# %%
import requests, json, datetime, pymysql, sys, csv, difflib, re
from geopy import distance

# %%
def get_direct_goo():
    
#     postA = "Fairview, County Dublin, Ireland"
#     postB = "Killiney, County Dublin, Ireland"

#     postA = "Heuston Station, Saint John's Road West, Dublin, Ireland"
#     postB = "Temple Bar, Dublin, Ireland"

#     postA = "University College Dublin, Belfield, Dublin, Ireland"
#     postB ="Temple Bar, Dublin, Ireland"

    postA = "Fairview, County Dublin, Ireland"
    postB = "Killiney, County Dublin, Ireland"

    api_key = 'AIzaSyBi-bH5_sngxNibrgygRZDhmAv2fK5hzus'
    url ='https://maps.googleapis.com/maps/api/directions/json?alternatives=true&transit_mode=bus&'

    req = requests.get(url + 'origin=' + postA +'&destination=' + postB
                     +'&sensor='+"false"+'&mode='+"transit"+'&key=' + api_key)

    return req.json()

a = get_direct_goo()

# %%
a.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
# Everything together
a["routes"]
# Out:
# [{'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1068089},
#    'southwest': {'lat': 53.2648407, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '6:51pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562953860},
#     'departure_time': {'text': '5:04pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562947495},
#     'distance': {'text': '21.4 km', 'value': 21351},
#     'duration': {'text': '1 hour 46 mins', 'value': 6365},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2648407, 'lng': -6.1150125},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.9 km', 'value': 2948},
#       'duration': {'text': '15 mins', 'value': 907},
#       'end_location': {'lat': 53.3478299, 'lng': -6.258418400000001},
#       'html_instructions': 'Bus towards Jobstown',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBBBA@@@tGjDr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHhBZvDPAFzE'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3478299,
#          'lng': -6.258418400000001},
#         'name': 'Clifton Court Hotel Eden Quay'},
#        'arrival_time': {'text': '5:20pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562948442},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '5:05pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562947535},
#        'headsign': 'Jobstown',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 9},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 95},
#       'duration': {'text': '1 min', 'value': 79},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#       'steps': [{'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 38},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>',
#         'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@'},
#         'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCj@U'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '12.1 km', 'value': 12071},
#       'duration': {'text': '44 mins', 'value': 2622},
#       'end_location': {'lat': 53.29017030000001, 'lng': -6.131013},
#       'html_instructions': 'Bus towards Brides Glen',
#       'polyline': {'points': 'gkrdIjlee@DRrA{@n@u@zBqDNOJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@h@cEf@uDP_B@CBUBg@@S@e@JQDIBGLa@DMTeAFOb@kBTy@DQ`@_BNm@x@gD~AqGH]@?VeARu@V_AViA^uAPs@FWVgAFWh@_Cb@cBPm@VaAFWDOVcALo@BILc@DUH]`@mBP}@h@gCFSHSPg@JORa@x@_BVe@NW^o@l@_Az@wANOf@_@@Af@]^[v@c@d@Wx@i@j@]l@a@TMnCgB`Ao@NIZSx@e@h@]XOPQ~@u@^k@V_@HMlDoENQJQJS`@k@x@iAf@y@n@kAXs@t@}BFUBETq@BIFQLg@Jk@BGFa@HU@CFKBMJi@BIDSHg@Ny@Lq@VyAZaBNaARiAPaATmAJe
start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.9 km', 'value': 2944},
#       'duration': {'text': '12 mins', 'value': 732},
#       'end_location': {'lat': 53.34775459999999, 'lng': -6.2584683},
#       'html_instructions': 'Bus towards Eden Quay',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBB?ArA|ApBrBzLtGr@x@t@X~@?z@Oj@FBfH?jI?UHrDPhBlArN'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.34775459999999,
#          'lng': -6.2584683},
#         'name': 'Dublin, Eden Quay'},
#        'arrival_time': {'text': '5:23pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562948625},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '5:11pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562947893},
#        'headsign': 'Eden Quay',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27b',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 8},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 101},
#       'duration': {'text': '1 min', 'value': 83},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'onrdIniee@Hr@@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.34776189999999, 'lng': -6.258322499999999},
#       'steps': [{'distance': {'text': '56 m', 'value': 56},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>',
#         'polyline': {'points': 'onrdIniee@Hr@@JHh@Ht@'},
#         'start_location': {'lat': 53.34776189999999,
#          'lng': -6.258322499999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 
warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1068089},
#    'southwest': {'lat': 53.2648407, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '6:51pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562953860},
#     'departure_time': {'text': '5:06pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562947599},
#     'distance': {'text': '21.7 km', 'value': 21669},
#     'duration': {'text': '1 hour 44 mins', 'value': 6261},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2648407, 'lng': -6.1150125},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '3.1 km', 'value': 3077},
#       'duration': {'text': '11 mins', 'value': 668},
#       'end_location': {'lat': 53.3482982, 'lng': -6.2557009},
#       'html_instructions': 'Bus towards Eden Quay',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@Cf@AFAF?H?D?L@HBH@DDJFd@@R@BDb@JtABA|ApPr@e@dAs@zBeAAqCH}@h@yBb@o@l@a@z@Oj@FBfH?jI?UHrDFf@UJ'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3482982,
#          'lng': -6.2557009},
#         'name': 'Dublin City, Eden Quay'},
#        'arrival_time': {'text': '5:18pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562948307},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '5:07pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562947639},
#        'headsign': 'Eden Quay',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27a',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 9},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.3 km', 'value': 284},
#       'duration': {'text': '4 mins', 'value': 218},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'kqrdI|xde@Dl@\\pENpABRFf@d@vD@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.3482206, 'lng': -6.255670599999999},
#       'steps': [{'distance': {'text': '0.2 km', 'value': 239},
#         'duration': {'text': '3 mins', 'value': 177},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Marlborough St</b>',
#         'polyline': {'points': 'kqrdI|xde@Dl@\\pENpABRFf@d@vD@JHh@Ht@'},
#         'start_location': {'lat': 53.3482206, 'lng': -6.255670599999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCj@U'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '12.1 km', 'value': 12071},
#       'duration': {'text': '44 mins', 'value': 2622},
#       'end_location': {'lat': 53.29017030000001, 'lng': -6.131013},
#       'html_instructions': 'Bus towards Brides Glen',
#       'polyline': {'points': 'gkrdIjlee@DRrA{@n@u@zBqDNOJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@h@cEf@uDP_B@CBUBg@@S@e@JQDIBGLa@DMTeAFOb@kBTy@DQ`@_BNm@x@gD~AqGH]@?VeARu@V_AViA^uAPs@FWVgAFWh@_Cb@cBPm@VaAFWDOVcALo@BILc@DUH]`@mBP}@h@gCFSHSPg@JORa@x@_BVe@NW^o@l@_Az@wANOf@_@@Af@]^[v@c@d@Wx@i@j@]l@a@TMnCgB`Ao@NIZSx@e@h@]XOPQ~@u@^k@V_@HMlDoENQJQJS`@k@x@iAf@y@n@kAXs@t@}BFUBETq@BIFQLg@Jk@BGFa@HU@CFKBMJi@BIDSHg@Ny@Lq@VyAZaBNaARiAPaATmAJe@FWH[Jc@Rk@JYNYNWX]ZYTUh@c@RW`Aw@DCDG\\a@n@aAR]Xc@h@cALS?ARa@JQVg@Rc@n@mAjAcCn@qABEx@cBbAuBh@aAnAmBHMPUJMt@aAHKt@eANQ\\i@`@k@FKfAcBb@y@h@cAFMd@aA^w@JQ`@w@Zo@@EDIHQLW^w@BS`@}@L[Pc@b@cAN]LY^w@b@kAVq@Tu@Le@H[R_ABIDQ@CTeA@GP}@@EF]Hg@F]Jq@F_@FYNw@TkAXsAJ_@No@DYRy@XeAR}@HWL[Pg@N_@N[BGHSTk@BERa@bAoBVi@`@q@R[?Ah@w@D
DwC`AeAbAiBbHqNvB}F|D_Ih@wBNkANw@`@yC`@oCf@gC~@yCfByCpCkEv@aBpCgGn@}BxBwFhDeGP_@B_@ZgAVgAPs@LmALkBWgA]_C?m@FcAn@cER}@Na@zAsChAiA\\SjAmA|AiCp@kB`@kAt@{BnAuCjAmBRMp@aBjBwEv@eBb@i@fAkAtAcAZMHs@p@sE~AkLvD}f@zAaRl@oHZ{ECsAOcCV}IEsEY_Dc@cC{AcH{@iDYeBEwDLkIFkE_DIQCMGU_@GW[YAi@EsAAoABaDDkAnAwIlAkIXgBtAaFVeAt@gCdAdAb@b@rClCjCpCb@b@^iAZaAx@iCzDkL`BaFX}@GIFHRm@bBaF~@qCnDiKdCqHXaARuAhBsNVaBdAuCh@{AP}AHyBBuHD{ERsFj@kNj@kKvA}I^cBTc@v@}@`AuB|@{Bf@i@r@UjAGvBNpDXnBXp@Hj@ExAWjC]nCRlAPRNBRKzAErAB~AnArKb@xCl@tF^zEMjE[|IDrADvA@B@NRrBV`A~@fGj@xDbAzCTKPDXh@B\\ANN`@pAzA~IdH`@Z@AB?@@FF?DhA|Ab@dAbArDvCxJ`CpGl@nA@?B?BD@D?@l@x@rArAdDgNjAaHk@cBm@_Eq@sC}AkGm@uA}CaFSgAEe@AKPGHGFE\\g@j@eB`@kCJcAvAoOd@_FRwBJHl@LfAJn@Qj@c@\\Gt@Jd@C?A@C@ABAFH?BXNz@f@z@r@dCv@t@RlAP^D`A[tA}@RIJ??J'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1149969},
#    'southwest': {'lat': 53.2650017, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '7:09pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562954971},
#     'departure_time': {'text': '5:24pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562948695},
#     'distance': {'text': '18.6 km', 'value': 18620},
#     'duration': {'text': '1 hour 45 mins', 'value': 6276},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.9 km', 'value': 2948},
#       'duration': {'text': '15 mins', 'value': 907},
#       'end_location': {'lat': 53.3478299, 'lng': -6.258418400000001},
#       'html_instructions': 'Bus towards Jobstown',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBBBA@@@tGjDr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHhBZvDPAFzE'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3478299,
#          'lng': -6.258418400000001},
#         'name': 'Clifton Court Hotel Eden Quay'},
#        'arrival_time': {'text': '5:40pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562949642},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '5:25pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562948735},
#        'headsign': 'Jobstown',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 9},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.2 km', 'value': 186},
#       'duration': {'text': '3 mins', 'value': 163},
#       'end_location': {'lat': 53.3465171, 'lng': -6.2582432},
#       'html_instructions': "Walk to Dublin City South, D'Olier Street",
#       'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@NEHIFCz@]JGJERGJGLOJOVe@NW?A'},
#       'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#       'steps': [{'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 38},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>',
#         'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@'},
#         'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '69 m', 'value': 69},
#         'duration': {'text': '1 min', 'value': 62},
#         'end_location': {'lat': 53.34700729999999, 'lng': -6.2588019},
#         'html_instructions': "Turn <b>left</b> onto <b>O'Connell Bridge</b>",
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCz@]JGJE'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '67 m', 'value': 67},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3465171, 'lng': -6.2582432},
#         'html_instructions': 'Continue straight onto <b>D\'Olier Street</b>/<b>R138</b><div style="font-size:0.9em">Continue to follow D\'Olier Street</div><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'straight',
#         'polyline': {'points': 'yirdInlee@RGJGLOJOVe@NW?A'},
#         'start_location': {'lat': 53.34700729999999, 'lng': -6.2588019},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING
FaAE[?gAA@KBUC]SIUCMAOAI?QBOBUJYNMLK`@Yh@c@`Bi@j@SZOHGRQh@e@@AZUTSf@[n@[\\OlAc@fDoA^Sn@Yh@YLMTQFEVMBABAd@MHCRE@?HAH?L?NA`@GF?NCh@IPCdAS^gA^q@rCoF^q@vBaElBuDbAkBdBcDnAaCr@qAd@}@BENYdAoBhAyBbBgD`AkB\\q@\\o@pE}IVe@Xm@|CgG|CaGZm@d@eAFOP[b@aArAqCZq@v@wA^q@P[HOTc@BIh@eArAoCTg@`D{GTm@Rg@Zw@BGTk@IM'},
#       'start_location': {'lat': 53.34657790000001, 'lng': -6.2581425},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.267062,
#          'lng': -6.136234099999999},
#         'name': 'Sallynoggin, Killiney Shopping Centre'},
#        'arrival_time': {'text': '6:43pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562953432},
#        'departure_stop': {'location': {'lat': 53.34657790000001,
#          'lng': -6.2581425},
#         'name': "Dublin City South, D'Olier Street"},
#        'departure_time': {'text': '5:49pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562950159},
#        'headsign': 'Shankill',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '7b',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 36},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '1.8 km', 'value': 1795},
#       'duration': {'text': '25 mins', 'value': 1523},
#       'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#       'html_instructions': 'Walk to Scalpwilliam, Killiney, Co. Dublin, Ireland',
#       'polyline': {'points': 'yubdIznmd@Xw@JSDWHSBOBQ@O?M?QEYAECG?CAEAGAK?K?I?G@G@KDMBIBCBEBCFEDCFSBODe@@YAYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yCJKZ_@P[T]NWHUDKFSDMLcAPcAHg@Fg@`A{@NObAo@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_AV?H_@HYHMl@iAXk@Rk@`@cAb@oADYI{@PBL@TCj@Wh@c@j@Y'},
#       'start_location': {'lat': 53.2670131, 'lng': -6.136298300000001},
#       'steps': [{'distance': {'text': '33 m', 'value': 33},
#         'duration': {'text': '1 min', 'value': 25},
#         'end_location': {'lat': 53.26681910000001, 'lng': -6.1359166},
#         'html_instructions': 'Head <b>southeast</b> on <b>Rochestown Ave</b>/<b>R828</b>',
#         'polyline': {'points': 'yubdIznmd@Xw@JS'},
#         'start_location': {'lat': 53.2670131, 'lng': -6.136298300000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '54 m', 'value': 54},
#         'duration': {'text': '1 min', 'value': 46},
#         'end_location': {'lat': 53.2667168, 'lng': -6.1351584},
#         'html_instructions': 'Slight <b>left</b> to stay on <b>Rochestown Ave</b>/<b>R828</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'stbdInlmd@DWHSBOBQ@O?M?QEY'},
#         'start_location': {'lat': 53.26681910000001, 'lng': -6.1359166},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.8 km', 'value': 800},
#         'duration': {'text': '11 mins', 'value': 647},
#         'end_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'html_instructions': 'At <b>Graduate Roundabout</b>, take the <b>3rd</b> exit onto <b>Ballinclea Rd</b>',
#         'maneuver': 'roundabout-left',
#         'polyline': {'points': '_tbdIvgmd@AECG?CAEAGAK?K?I?G@G@KDMBIBCBEBCFEDCFSBODe@@YAYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yC'},
#         'start_location': {'lat': 53.2667168, 'lng': -6.1351584},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '90 m', 'value': 90},
#         'duration': {'text': '1 min', 'value': 80},
#         'end_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'html_instructions': 'Turn <b>right</b> toward <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'ydcdI|gkd@JKZ_@P[T]NWHUDKFS'},
#         'start_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 176},
#         'duration': {'text': '3 mins', 'value': 161},
#         'end_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'html_instructions': 'Continue onto <b>Ballinclea Heights</b>',
#         'polyline': {'points': 'aacdIhbkd@DMLcAPcAHg@Fg@`A{@NObAo@'},
#         'start_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.3 km', 'value': 324},
#         'duration': {'text': '4 mins', 'value': 269},
#         'end_location': {'lat': 53.2669794, 'lng': -6.1177607},
#         'html_instructions': 'Turn <b>left</b> to stay on <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'szbdIfwjd@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_A'},
#         'start_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '13 m', 'value': 13},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.26685939999999, 'lng': -6.1177624},
#         'html_instructions': 'Turn <b>right</b> onto <b>Rock Lodge</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'subdI~zid@V?'},
#         'start_location': {'lat': 53.2669794, 'lng': -6.1177607},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 176},
#         'duration': {'text': '3 mins', 'value': 176},
#         'end_location': {'lat': 53.26587, 'lng': -6.11572},
#         'html_instructions': 'Turn <b>left</b> to stay on <b>Rock Lodge</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': '{tbdI~zid@H_@HYHMl@iAXk@Rk@`@cAb@oADY'},
#         'start_location': {'lat': 53.26685939999999, 'lng': -6.1177624},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '21 m', 'value': 21},
#         'duration': {'text': '1 min', 'value': 20},
#         'end_location': {'lat': 53.2659218, 'lng': -6.115418699999999},
#         'html_instructions': 'Slight <b>left</b> onto <b>Claremont Rd</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'unbdIfnid@I{@'},
#         'start_location': {'lat': 53.26587, 'lng': -6.11572},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 108},
#         'duration': {'text': '1 min', 'value': 84},
warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
# Shows all different trip options worked out by google
route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]    
route_keys
# Out:
# [dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])]

# %%
a["routes"][0]["bounds"]
# Out:
# {'northeast': {'lat': 53.36490269999999, 'lng': -6.1068089},
#  'southwest': {'lat': 53.2648407, 'lng': -6.2595337}}

# %%
# Shows all the steps in a trip
for i, val in enumerate(a["routes"][0]["legs"][0]["steps"]):
    print(i)
    print(val)
# Out:
# 0
# {'distance': {'text': '58 m', 'value': 58}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 53.3646089, 'lng': -6.2294807}, 'html_instructions': 'Walk to Marino, East South B. Sub Station', 'polyline': {'points': 'syudIjy_e@|@_CCC'}, 'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364}, 'steps': [{'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 37}, 'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001}, 'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>", 'polyline': {'points': 'syudIjy_e@|@_C'}, 'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364}, 'travel_mode': 'WALKING'}, {'distance': {'text': '3 m', 'value': 3}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 53.3646089, 'lng': -6.2294807}, 'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'uwudIju_e@CC'}, 'start_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}
# 1
# {'distance': {'text': '2.9 km', 'value': 2948}, 'duration': {'text': '15 mins', 'value': 907}, 'end_location': {'lat': 53.3478299, 'lng': -6.258418400000001}, 'html_instructions': 'Bus towards Jobstown', 'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBBBA@@@tGjDr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHhBZvDPAFzE'}, 'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'transit_details': {'arrival_stop': {'location': {'lat': 53.3478299, 'lng': -6.258418400000001}, 'name': 'Clifton Court Hotel Eden Quay'}, 'arrival_time': {'text': '5:20pm', 'time_zone': 'Europe/Dublin', 'value': 1562948442}, 'departure_stop': {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}, 'departure_time': {'text': '5:05pm', 'time_zone': 'Europe/Dublin', 'value': 1562947535}, 'headsign': 'Jobstown', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '27', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 9}, 'travel_mode': 'TRANSIT'}
# 2
# {'distance': {'text': '0.1 km', 'value': 95}, 'duration': {'text': '1 min', 'value': 79}, 'end_location': {'lat': 53.3472145, 'lng': -6.2589095}, 'html_instructions': "Walk to O'Connell Bridge Bus Stop", 'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@NEHIFCj@U'}, 'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999}, 'steps': [{'distance': {'text': '50 m', 'value': 50}, 'duration': {'text': '1 min', 'value': 38}, 'end_location': {'lat': 53.3475955, 'lng': -6.2591161}, 'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>', 'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@'}, 'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '45 m', 'value': 45}, 'duration': {'text': '1 min', 'value': 41}, 'end_location': {'lat': 53.3472145, 'lng': -6.2589095}, 'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'omrdInnee@NEHIFCj@U'}, 'start_location': {'lat': 53.3475955, 'lng': -6.2591161}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}
# 3
# {'distance': {'text': '12.1 km', 'value': 12071}, 'duration': {'text': '44 mins', 'value': 2622}, 'end_location': {'lat': 53.29017030000001, 'lng': -6.131013}, 'html_instructions': 'Bus towards Brides Glen', 'polyline': {'points': 'gkrdIjlee@DRrA{@n@u@zBqDNOJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@h@cEf@uDP_B@CBUBg@@S@e@JQDIBGLa@DMTeAFOb@kBTy@DQ`@_BNm@x@gD~AqGH]@?VeARu@V_AViA^uAPs@FWVgAFWh@_Cb@cBPm@VaAFWDOVcALo@BILc@DUH]`@mBP}@h@gCFSHSPg@JORa@x@_BVe@NW^o@l@_Az@wANOf@_@@Af@]^[v@c@d@Wx@i@j@]l@a@TMnCgB`Ao@NIZSx@e@h@]XOPQ~@u@^k@V_@HMlDoENQJQJS`@k@x@iAf@y@n@kAXs@t@}BFUBETq@BIFQLg@Jk@BGFa@HU@CFKBMJi@BIDSHg@Ny@Lq@VyAZaBNaARiAPaATmAJe@FWH[Jc@Rk@JYNYNWX]ZYTUh@c@RW`Aw@DCDG\\a@n@aAR]Xc@h@cALS?ARa@JQV
vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 20}, 'travel_mode': 'TRANSIT'}

# %%
# Shows only steps with bus 
print(a["routes"][0]["legs"][0]["steps"][1]["transit_details"])
# Out:
# {'arrival_stop': {'location': {'lat': 53.3478299, 'lng': -6.258418400000001}, 'name': 'Clifton Court Hotel Eden Quay'}, 'arrival_time': {'text': '5:20pm', 'time_zone': 'Europe/Dublin', 'value': 1562948442}, 'departure_stop': {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}, 'departure_time': {'text': '5:05pm', 'time_zone': 'Europe/Dublin', 'value': 1562947535}, 'headsign': 'Jobstown', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '27', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 9}

# %%
print("vehicle: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["vehicle"]["type"])
print()
print("dep stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"])
print()
print("arr stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"])
print()
print("headsign: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["headsign"])
print()
print("route name: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["short_name"])
print()
print("num_stops: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["num_stops"])
print()
print("dep time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
print()
print("arri time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
print()
arr = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
dep = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
tot = datetime.timedelta(seconds=(arr - dep))
print("total time: ", tot)
# Out:
# vehicle:  BUS
#
# dep stop:  {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}
#
# arr stop:  Clifton Court Hotel Eden Quay
#
# headsign:  Jobstown
#
# route name:  27
#
# num_stops:  9
#
# dep time:  1562947535
#
# arri time:  1562948442
#
# total time:  0:15:07

# %%
for i in range(len(route_keys)):
    for j in range(len(a["routes"][i]["legs"][0]["steps"])):
    
        if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
            print("lat-lon dep: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["location"])
            
            print("lat-lon arr: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["location"])
            
            print("Vehicle: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"])
            
            print("dep stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"])
            
            print("arr stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"])
            
            print("headsign: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"])
                  
            print("route name: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"])
                  
            print("num_stops: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["num_stops"])
            
            arr = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_time"]["value"])
            dep = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_time"]["value"])
            tot = datetime.timedelta(seconds=(arr - dep))
            print("totalbus trip time: ", tot)
                  
            print("step number", j)
            print("option number:", i)
            print()
            
    print("-----------------------------------------------------")
    print()
# Out:
# lat-lon dep:  {'lat': 53.36457499999999, 'lng': -6.2293973}
# lat-lon arr:  {'lat': 53.3478299, 'lng': -6.258418400000001}
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Clifton Court Hotel Eden Quay
# headsign:  Jobstown
# route name:  27
# num_stops:  9
# totalbus trip time:  0:15:07
# step number 1
# option number: 0
#
# lat-lon dep:  {'lat': 53.3472395, 'lng': -6.258775900000001}
# lat-lon arr:  {'lat': 53.29017030000001, 'lng': -6.131013}
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  George's St Upper
# headsign:  Brides Glen
# route name:  7
# num_stops:  37
# totalbus trip time:  0:43:42
# step number 3
# option number: 0
#
# lat-lon dep:  {'lat': 53.29017030000001, 'lng': -6.131013}
# lat-lon arr:  {'lat': 53.2648407, 'lng': -6.1150125}
# Vehicle:  BUS
# dep stop:  George's St Upper
# arr stop:  Killiney, Killiney Hill Road
# headsign:  Town Hall - Ballymount Depot
# route name:  59
# num_stops:  20
# totalbus trip time:  0:20:00
# step number 4
# option number: 0
#
# -----------------------------------------------------
#
# lat-lon dep:  {'lat': 53.36457499999999, 'lng': -6.2293973}
# lat-lon arr:  {'lat': 53.34775459999999, 'lng': -6.2584683}
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Dublin, Eden Quay
# headsign:  Eden Quay
# route name:  27b
# num_stops:  8
# totalbus trip time:  0:12:12
# step number 1
# option number: 1
#
# lat-lon dep:  {'lat': 53.3472395, 'lng': -6.258775900000001}
# lat-lon arr:  {'lat': 53.29017030000001, 'lng': -6.131013}
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  George's St Upper
# headsign:  Brides Glen
# route name:  7
# num_stops:  37
# totalbus trip time:  0:43:42
# step number 3
# option number: 1
#
# lat-lon dep:  {'lat': 53.29017030000001, 'lng': -6.131013}
# lat-lon arr:  {'lat': 53.2648407, 'lng': -6.1150125}
# Vehicle:  BUS
# dep stop:  George's St Upper
# arr stop:  Killiney, Killiney Hill Road
# headsign:  Town Hall - Ballymount Depot
# route name:  59
# num_stops:  20
# totalbus trip time:  0:20:00
# step number 4
# option number: 1
#
# -----------------------------------------------------
#
# lat-lon dep:  {'lat': 53.36457499999999, 'lng': -6.2293973}
# lat-lon arr:  {'lat': 53.3482982, 'lng': -6.2557009}
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Dublin City, Eden Quay
# headsign:  Eden Quay
# route name:  27a
# num_stops:  9
# totalbus trip time:  0:11:08
# step number 1
# option number: 2
#
# lat-lon dep:  {'lat': 53.3472395, 'lng': -6.258775900000001}
# lat-lon arr:  {'lat': 53.29017030000001, 'lng': -6.131013}
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  George's St Upper
# headsign:  Brides Glen
# route name:  7
# num_stops:  37
# totalbus trip time:  0:43:42
# step number 3
# option number: 2
#
# lat-lon dep:  {'lat': 53.29017030000001, 'lng': -6.131013}
# lat-lon arr:  {'lat': 53.2648407, 'lng': -6.1150125}
# Vehicle:  BUS
# dep stop:  George's St Upper
# arr stop:  Killiney, Killiney Hill Road
# headsign:  Town Hall - Ballymount Depot
# route name:  59
# num_stops:  20
# totalbus trip time:  0:20:00
# step number 4
# option number: 2
#
# -----------------------------------------------------
#
# lat-lon dep:  {'lat': 53.36457499999999, 'lng': -6.2293973}
# lat-lon arr:  {'lat': 53.3478299, 'lng': -6.258418400000001}
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Clifton Court Hotel Eden Quay
# headsign:  Jobstown
# route name:  27
# num_stops:  9
# totalbus trip time:  0:15:07
# step number 1
# option number: 3
#
# lat-lon dep:  {'lat': 53.34657790000001, 'lng': -6.2581425}
# lat-lon arr:  {'lat': 53.267062, 'lng': -6.136234099999999}
# Vehicle:  BUS
# dep stop:  Dublin City South, D'Olier Street
# arr stop:  Sallynoggin, Killiney Shopping Centre
# headsign:  Shankill
# route name:  7b
# num_stops:  36
# totalbus trip time:  0:54:33
# step number 3
# option number: 3
#
# -----------------------------------------------------

# %%
# This are stop names not addresses:

# stopA = "Outside Heuston Train Station"
# stopB = "Temple Bar, Parliament Street"

stopA = "Marino, East South B. Sub Station"
stopB = "Clifton Court Hotel Eden Quay"

# stopA = "O'Connell Bridge Bus Stop"
# stopB = "Glenageary Heights, Sallyglen"

# stopA = "Dublin City South, Camden Street"
# stopB = "Fairview, Marino College Fairview"

# stopA = "Dublin (UCD Stillorgan Rd Flyover)"
# stopB = "Dublin City South, Essex Quay"

# stopA = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"]["name"]
# stopB = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"]
# print(stopA)
# print(stopB)


query1 = """SELECT stop_lat,stop_lon,stop_id,stop_name 
        FROM research.stops 
        WHERE stop_name LIKE %s or stop_name LIKE %s"""

queryLatLon = """SELECT stop_lat, stop_lon, stop_id, stop_name 
            FROM research.stops, research.stop_times
            WHERE research.stop_times.bus_stop_number = research.stops.stop_id 
                and research.stop_times.bus_number = %s
                and research.stop_times.headsign = %s
                and ((stop_lat BETWEEN %s and %s) and (stop_lon BETWEEN %s and %s));"""

query2 = """SELECT distinct research.stop_times.bus_number  
        FROM research.stop_times 
        WHERE research.stop_times.bus_number = %s and research.stop_times.bus_stop_number = %s and research.stop_times.headsign = %s"""


query3 = """SELECT distinct research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.trips.direction_id, research.stop_times.headsign 
        FROM research.stop_times, research.trips 
        WHERE stop_times.headsign = %s 
            and stop_times.bus_number = %s 
            and (stop_times.bus_stop_number = %s or stop_times.bus_stop_number = %s)"""


query4 = """SELECT research.stops.stop_lat, research.stops.stop_lon, research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.stop_times.headsign, research.stop_times.bus_number 
        FROM research.stop_times, research.stops
        WHERE research.stop_times.bus_number = %s and research.stop_times.headsign = %s and (research.stop_times.stop_sequence between %s AND %s)
        LIMIT %s
        """

# %%
def lat_lon(query, busNo, head_sign, golatA, golonA, golatB, golonB):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)
    
    latA = round(float(golatA),4)
    lonA = round(float(golonA),4)
    
    latB = round(float(golatB),4)
    lonB = round(float(golonB),4)
    
    data = []
    
    cur = con.cursor()
    cur.execute(query, (busNo, head_sign, latA-0.003, latA+0.003, lonA-0.003, lonA+0.003), )
    dataA = cur.fetchall()
    cur.close()
    data += dataA
                
    cur = con.cursor()
    cur.execute(query, (busNo, head_sign, latB-0.003, latB+0.003, lonB-0.003, lonB+0.003), )
    dataB = cur.fetchall()
    cur.close()
    data += dataB
    

    return tuple(data)

# %%
# ltA = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"]["location"]["lat"]
# lgA = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"]["location"]["lng"]

# ltB = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["location"]["lat"]
# lgB = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["location"]["lng"]

# lat_lon(queryLatLon, ltA, lgA, ltB, lgB)

# %%
def db_query2(query, bus_no, stop_no, head_sign):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)
    
    cur = con.cursor()
    cur.execute(query, (bus_no, stop_no, head_sign),)
    data = list(cur.fetchall())

    if len(data) > 0:
        data.pop()
        data.append(bus_no)
        data.append(head_sign)

    cur.close()

    return data

# %%
def start_end(b, bus_no, head_sign):
# def start_end(b):
    c = []
    
    for i in b:
#         z = db_query2(query2, "145", i[2], "Heuston Station")
        z = db_query2(query2, bus_no, i[2], head_sign)

        if(len(z) != 0):
            z.append(i[0])
            z.append(i[1])
            z.append(i[2])
            z.append(i[3])
            c.append(z)
            

    return c

# %%
def db_query3(query, head_sign, bus_no, stop_noA, stop_noB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    cur = con.cursor()
    cur.execute(query, (head_sign, bus_no, stop_noA, stop_noB),)
    cur.close()
    return cur.fetchall()

# %%
# e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])
# e

# %%
def db_query4(query, bus_no, head_sign, seqA, seqB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
    limit = seqB - seqA + 1
    cur = con.cursor()
    cur.execute(query, (bus_no, head_sign, seqA, seqB, limit),)
    cur.close()
    return cur.fetchall()

# %%
# f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
# f

# %%
# a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS"
# a["routes"][0]["legs"][0]["steps"][0]

# %%
final_list = []

def fin(a):
    
    route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]
    
    for i in range(len(route_keys)):
        should_count = 0
        is_count = 0
        interm_legs = []
        for j in range(len(a["routes"][i]["legs"][0]["steps"])):
            
            if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
                should_count += 1
                dep_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"].strip()
                arr_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"].strip()
                bus_no = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"].strip()
                head_sign = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"].strip()
                print(bus_no)
                print(head_sign)
                
                latA = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["location"]["lat"]
                lonA = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["location"]["lng"]
                
                latB = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["location"]["lat"]
                lonB = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["location"]["lng"]
                
                b = lat_lon(queryLatLon, bus_no, head_sign, latA, lonA, latB, lonB)
#                 b = db_query(query1, dep_stop, arr_stop)
                print("Query 1: ")
                print(b)
                if len(b) > 1:
                    d = start_end(b, bus_no, head_sign)
                    print("Query 2: ")
                    print(d)
                    
                    if len(d) > 1:
                        e = db_query3(query3, head_sign, bus_no, dep_stop, arr_stop) 
                        print("Query 3: ")
                        print(e)
                        if (len(e) > 0):
                            f = db_query4(query4, bus_no, head_sign, e[0][1], e[1][1])
                            print("Final: ")
                            print(f)
                            is_count += 1
                            interm_legs.append(f)                            

                        else:
                            pass
                    else:
                        pass
                else:
                    pass
                print("step: ", j)
            else:
                pass
            
            
            
        if should_count == is_count:
            print("Number of positive legs obtained: ", len(interm_legs))
            final_list.append(interm_legs)
        else:
            print("Number of positive legs is NOT valid with", len(interm_legs))
                
        
        print("option: ", i)
        print("*****************************************************************")
fin(a)
# Out:
# 27
# Jobstown
# Query 1:
# ((53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3481, -6.2564, '8220DB000302', 'Dublin, Eden Quay'), (53.3462, -6.25697, '8220DB004495', "Dublin City South, Hawkin's Street"))
# Query 2:
# [['27', 'Jobstown', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27', 'Jobstown', 53.3481, -6.2564, '8220DB000302', 'Dublin, Eden Quay'], ['27', 'Jobstown', 53.3462, -6.25697, '8220DB004495', "Dublin City South, Hawkin's Street"]]
# 3 busno: 27
# 3 stopA: Marino, East South B. Sub Station
# 3 stopB: Clifton Court Hotel Eden Quay
# 3 Headsign: Jobstown
# Query 3:
# ()
# step:  1
# 7
# Brides Glen
# Query 1:
# ((53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"), (53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"), (53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"))
# Query 2:
# [['7', 'Brides Glen', 53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"], ['7', 'Brides Glen', 53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"], ['7', 'Brides Glen', 53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"]]
# 3 busno: 7
# 3 stopA: O'Connell Bridge Bus Stop
# 3 stopB: George's St Upper
# 3 Headsign: Brides Glen
# Query 3:
# ()
# step:  3
# 59
# Town Hall - Ballymount Depot
# Query 1:
# ()
# step:  4
# Number of positive legs is NOT valid with 0
# option:  0
# *****************************************************************
# 27b
# Eden Quay
# Query 1:
# ((53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'), (53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'))
# Query 2:
# [['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay'], ['27b', 'Eden Quay', 53.3481, -6.25598, '8220DB000303', 'Dublin, Eden Quay']]
# 3 busno: 27b
# 3 stopA: Marino, East South B. Sub Station
# 3 stopB: Dublin, Eden Quay
# 3 Headsign: Eden Quay
# Query 3:
# ()
# step:  1
# 7
# Brides Glen
# Query 1:
# ((53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"), (53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"), (53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"))
# Query 2:
# [['7', 'Brides Glen', 53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"], ['7', 'Brides Glen', 53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"], ['7', 'Brides Glen', 53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"]]
# 3 busno: 7
# 3 stopA: O'Connell Bridge Bus Stop
# 3 stopB: George's St Upper
# 3 Headsign: Brides Glen
# Query 3:
# ()
# step:  3
# 59
# Town Hall - Ballymount Depot
# Query 1:
# ()
# step:  4
# Number of positive legs is NOT valid with 0
# option:  1
# *****************************************************************
# 27a
# Eden Quay
# Query 1:
# ((53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3483, -6.25588, '8220DB007568', 'Dublin City, Eden Quay'), (53.3483, -6.25588, '8220DB007568', 'Dublin City, Eden Quay'))
# Query 2:
# [['27a', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27a', 'Eden Quay', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27a', 'Eden Quay', 53.3483, -6.25588, '8220DB007568', 'Dublin City, Eden Quay'], ['27a', 'Eden Quay', 53.3483, -6.25588, '8220DB007568', 'Dublin City, Eden Quay']]
# 3 busno: 27a
# 3 stopA: Marino, East South B. Sub Station
# 3 stopB: Dublin City, Eden Quay
# 3 Headsign: Eden Quay
# Query 3:
# ()
# step:  1
# 7
# Brides Glen
# Query 1:
# ((53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"), (53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"), (53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"))
# Query 2:
# [['7', 'Brides Glen', 53.3472, -6.25882, '8220DB000273', "Dublin City South, O'Connell Bridge"], ['7', 'Brides Glen', 53.2902, -6.13101, '8250DB003047', "Dun Laoghaire, Upper George's Street"], ['7', 'Brides Glen', 53.2888, -6.12996, '8250DB003202', "Glasthule, Lower Glenageary Road (Upper George's St)"]]
# 3 busno: 7
# 3 stopA: O'Connell Bridge Bus Stop
# 3 stopB: George's St Upper
# 3 Headsign: Brides Glen
# Query 3:
# ()
# step:  3
# 59
# Town Hall - Ballymount Depot
# Query 1:
# ()
# step:  4
# Number of positive legs is NOT valid with 0
# option:  2
# *****************************************************************
# 27
# Jobstown
# Query 1:
# ((53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'), (53.3481, -6.2564, '8220DB000302', 'Dublin, Eden Quay'), (53.3462, -6.25697, '8220DB004495', "Dublin City South, Hawkin's Street"))
# Query 2:
# [['27', 'Jobstown', 53.3646, -6.2294, '8220DB000668', 'Marino, East South B. Sub Station'], ['27', 'Jobstown', 53.3481, -6.2564, '8220DB000302', 'Dublin, Eden Quay'], ['27', 'Jobstown', 53.3462, -6.25697, '8220DB004495', "Dublin City South, Hawkin's Street"]]
# 3 busno: 27
# 3 stopA: Marino, East South B. Sub Station
# 3 stopB: Clifton Court Hotel Eden Quay
# 3 Headsign: Jobstown
# Query 3:
# ()
# step:  1
# 7b
# Shankill
# Query 1:
# ((53.3466, -6.25813, '8220DB000334', "Dublin City South, D'Olier Street"), (53.2671, -6.13623, '8250DB003213', 'Sallynoggin, Killiney Shopping Centre'), (53.2646, -6.13462, '8250DB003214', 'Killiney, Churchview Road'))
# Query 2:
# [['7b', 'Shankill', 53.3466, -6.25813, '8220DB000334', "Dublin City South, D'Olier Street"], ['7b', 'Shankill', 53.2671, -6.13623, '8250DB003213', 'Sallynoggin, Killiney Shopping Centre'], ['7b', 'Shankill', 53.2646, -6.13462, '8250DB003214', 'Killiney, Churchview Road']]
# 3 busno: 7b
# 3 stopA: Dublin City South, D'Olier Street
# 3 stopB: Sallynoggin, Killiney Shopping Centre
# 3 Headsign: Shankill
# Query 3:
# ()
# step:  3
# Number of positive legs is NOT valid with 0
# option:  3
# *****************************************************************

# %%
print(len(final_list))

# %%
final_list
