# %%
import requests, json, datetime, pymysql

# %%
def get_direct_goo():
    
#     "Fairview, County Dublin, Ireland"
#     "Greystones, County Wicklow, Ireland"

#     "Heuston Station, Saint John's Road West, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

#     "University College Dublin, Belfield, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

    postA = "University College Dublin, Belfield, Dublin, Ireland"
    postB = "Temple Bar, Dublin, Ireland"
    api_key = 'AIzaSyBi-bH5_sngxNibrgygRZDhmAv2fK5hzus'
    url ='https://maps.googleapis.com/maps/api/directions/json?alternatives=true&transit_mode=bus&'

    req = requests.get(url + 'origin=' + postA +'&destination=' + postB
                     +'&sensor='+"false"+'&mode='+"transit"+'&key=' + api_key)

    return req.json()

a = get_direct_goo()

# %%
a.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
# Everything together
a["routes"]
# Out:
# [{'bounds': {'northeast': {'lat': 53.3449392, 'lng': -6.2245418},
#    'southwest': {'lat': 53.3051888, 'lng': -6.267477299999999}},
#   'copyrights': 'Map data ©2019 Google',
#   'legs': [{'arrival_time': {'text': '5:38pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562603934},
#     'departure_time': {'text': '4:59pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562601553},
#     'distance': {'text': '7.9 km', 'value': 7872},
#     'duration': {'text': '40 mins', 'value': 2381},
#     'end_address': 'Temple Bar, Dublin, Ireland',
#     'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3081298, 'lng': -6.2245418},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 477},
#       'duration': {'text': '6 mins', 'value': 346},
#       'end_location': {'lat': 53.3082138, 'lng': -6.2303126},
#       'html_instructions': 'Walk to Belfield, University College of Dublin UCD',
#       'polyline': {'points': 'yvjdIjv~d@LD@?LDKfBAF?@@B?BB@B@ZDN@D@BB?@VFCp@AfAFXA@?@?@A??@?@?@?@?@?@?@?@@??@?@@??@?@CVIf@EjAKxB?PGbBChAAh@AVA^?p@A^?dA?lAA?A?A??@A?A@A@A@?@A@?@A@?@?@?@A??@?@?@?@?B[@UC'},
#       'start_location': {'lat': 53.3081298, 'lng': -6.2245418},
#       'steps': [{'distance': {'text': '8 m', 'value': 8},
#         'duration': {'text': '1 min', 'value': 6},
#         'end_location': {'lat': 53.3080577, 'lng': -6.224570399999999},
#         'html_instructions': 'Head <b>south</b>',
#         'polyline': {'points': 'yvjdIjv~d@LD'},
#         'start_location': {'lat': 53.3081298, 'lng': -6.2245418},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '8 m', 'value': 8},
#         'duration': {'text': '1 min', 'value': 6},
#         'end_location': {'lat': 53.3079832, 'lng': -6.224598599999999},
#         'html_instructions': 'Walk for 8&nbsp;m',
#         'polyline': {'points': 'kvjdIpv~d@@?LD'},
#         'start_location': {'lat': 53.3080577, 'lng': -6.224570399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text':

#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'yvjdIjv~d@NDLDKfBAH@FFBj@F`@NExBDZ?@?@AF?DBDCZIf@EjAKjCOnFCvDAlAA?C@A@CDCHAH?B[@UC@s@Ar@TBZC?E@C@IHKLBFN@RGPEBC@BnFBjCCxB[tCIbB?~Aj@jLxBNtCDdAAXC\\QZ]n@q@Lr@RdABf@Eb@L`@@p@@pIAlYAzG@fB_ARs@Ri@J}GlA}AVoALaAF{A?w@Cc@B_@Ji@\\[\\OTg@x@i@hBUz@`AXXJd@\\r@x@LRLNp@vAbBpDf@jARp@RbAVtDHjAHfBHnB@f@GpBo@rIk@jJ?zADjD?tACRMRWb@sAfBqBhC_@d@aAfAuBtBYPmAT}BLcBPs@JMFc@Za@\\AtBqAf@_HvCiEbB[B{AOqAWmA_@kAq@u@[{@SUA}@@w@RiAd@wAn@cB|@u@`@sBdAe@Lu@LKHYWUMkCYaBWqI}@iLoA_LgAmC]k@CU?cBZ_Cb@eL`BmAZM?MDYFi@AwDKeA?sAToAZk@FcAVuB\\s@PoBj@]?aC[sAS_AMoBWe@O}Ca@_@a@wBsBWOCN@OCA_@Oe@Gu@Gq@?y@@}BF?jD@bFHvCcDr@'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.34694409999999, 'lng': -6.2187873},
#    'southwest': {'lat': 53.3079626, 'lng': -6.267637499999999}},
#   'copyrights': 'Map data ©2019 Google',
#   'legs': [{'arrival_time': {'text': '5:45pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562604333},
#     'departure_time': {'text': '4:56pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562601404},
#     'distance': {'text': '8.4 km', 'value': 8387},
#     'duration': {'text': '49 mins', 'value': 2929},
#     'end_address': 'Temple Bar, Dublin, Ireland',
#     'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '64 m', 'value': 64},
#         'duration': {'text': '1 min', 'value': 43},
#         'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#         'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#         'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '7.8 km', 'value': 7766},
#       'duration': {'text': '41 mins', 'value': 2473},
#       'end_location': {'lat': 53.3454671, 'lng': -6.266250299999999},
#       'html_instructions': 'Bus towards Maynooth',
#       'polyline': {'points': 'y~jdI|r}d@GMMTMTi@~@_@h@y@jA]\\YXYRKHSFM@GAKHi@`@IFk@^yA`AA@aAp@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZi@xASd@Uf@Uf@o@dAOXm@z@UX[b@QXs@dA_@f@yAxByA`CmB`DGJy@pAILSZg@v@IJCF[h@]n@KRu@t@A@EDQHQXg@p@OPKNCB}AzBEFk@x@Yj@q@fAKLGJw@nA[h@EFa@r@OXIPIROj@Q~BI^O^IRMXOTCFS^]p@Ub@

#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENGM[j@iAhBy@jA]\\s@l@_@PU?u@j@qCjB}B|As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEuAvDkBnDqBrCsAlBsDzFyDlGiAfBy@xAKRu@t@GFQHQXw@bAKNsC`EkArBSX{BtDYj@Y~@Q~BI^Yr@u@vAs@tAeBbCg@p@m@t@yAvBkCzDgBhCiC~D}BxCaB`CmAlB]bAk@pBMf@uAy@e@OmMgEwE_B_Bg@e@MiA_@CJmAhEITuAlCg@t@Yt@qC~CoBbDw@xAsBtD_@v@[`AgClJE\\?RlAjA`ElDpAlA`CtBb@ZT`@jA~EH^[\\qApA_BhBkAnA_@h@Q`@O`@eAs@cDyBkCmBw@s@YCUHEFINMp@_@vBQr@K^@DyA`IOHq@Gc@OaCc@iCg@XmE|@aKqCmAuBy@l@yFFe@F}@By@CQi@qBO{@ASDi@RkBBYSKYOwFwCw@_@QKS?QBQLILG`@}@~GQ~Aw@fHo@tGM|@@RC\\Kf@m@hDKx@GdAApA?f@L`A\\zALh@?L@X@h@Cz@uA@eAAy@?wAGS@LdAXhBfBpLx@tHlA|NLEMFf@lGnA_@'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.3449392, 'lng': -6.2187873},
#    'southwest': {'lat': 53.3079626, 'lng': -6.267477299999999}},
#   'copyrights': 'Map data ©2019 Google',
#   'legs': [{'arrival_time': {'text': '5:37pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562603824},
#     'departure_time': {'text': '4:59pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562601543},
#     'distance': {'text': '6.2 km', 'value': 6212},
#     'duration': {'text': '38 mins', 'value': 2281},
#     'end_address': 'Temple Bar, Dublin, Ireland',
#     'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '64 m', 'value': 64},
#         'duration': {'text': '1 min', 'value': 43},
#         'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#         'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#         'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '4.8 km', 'value': 4837},
#       'duration': {'text': '21 mins', 'value': 1278},
#       'end_location': {'lat': 53.34211670000001, 'lng': -6.2580928},
#       'html_instructions': 'Bus towards Heuston Station',
#       'polyline': {'points': 'y~jdI|r}d@GMMTMTi@~@_@h@y@jA]\\YXYRKHSFM@GAKHi@`@IFk@^yA`AA@aAp@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZi@xASd@Uf@Uf@o@dAOXm@z@UX[b@QXs@dA_@f@yAxByA`CmB`DGJy@pAILSZg@v@IJCF[h@]n@KRu@t@A@EDQH
999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '47 m', 'value': 47},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.344293, 'lng': -6.260852},
#         'html_instructions': '<b>Suffolk St</b> turns slightly <b>right</b> and becomes <b>Church Ln</b>',
#         'polyline': {'points': 'evqdIjyee@U?Q?k@A'},
#         'start_location': {'lat': 53.343866, 'lng': -6.2608644},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.4 km', 'value': 424},
#         'duration': {'text': '5 mins', 'value': 317},
#         'end_location': {'lat': 53.3441189, 'lng': -6.267224000000001},
#         'html_instructions': 'Turn <b>left</b> onto <b>College Green</b>/<b>R137</b><div style="font-size:0.9em">Continue to follow R137</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'yxqdIhyee@?\\BfA@\\@z@BfA?h@C^@R@`A@hABzABzA?f@?dA?dB?xB?n@?X@^BfADnA'},
#         'start_location': {'lat': 53.344293, 'lng': -6.260852},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#         'html_instructions': 'Turn <b>right</b> onto <b>Parliament St</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'wwqdIbage@yBd@i@L'},
#         'start_location': {'lat': 53.3441189, 'lng': -6.267224000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENGM[j@iAhBy@jA]\\s@l@_@PU?u@j@qCjB}B|As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEuAvDkBnDqBrCsAlBsDzFyDlGiAfBy@xAKRu@t@GFQHQXw@bAKNsC`EkArBSX{BtDYj@Y~@Q~BI^Yr@u@vAs@tAeBbCg@p@m@t@yAvBkCzDgBhCiC~D}BxCaB`CmAlB]bAk@pBy@xCsArEu@rBMj@[dAMn@g@|E[nBYjA_@dAk@fAo@|@[\\wA`A]NoAj@mAt@SASNOJkArAeBjBaAfAmCxC}B|BaClCqAtAk@`AKPIX[Su@g@sA}@wAeAsCuBc@[IAUDMHQh@o@rD]hAaAzFYjAqAWaCg@uCk@_D]AQaCg@_@MEZCXGh@]fDSnAkBtGIBU?}@AF~DBpBAr@JbI?lIDpDDnAyBd@i@L'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.34583259999999, 'lng': -6.2187873},
#    'southwest': {'lat': 53.3079626, 'lng': -6.267477299999999}},
#   'copyrights': 'Map data ©2019 Google',
#   'legs': [{'arrival_time': {'text': '5:41pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562604113},
#     'departure_time': {'text': '5:01pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562601688},
#     'distance': {'text': '6.4 km', 'value': 6384},
#     'duration': {'text': '40 mins', 'value': 2425},
#     'end_address': 'Temple Bar, Dublin, Ireland',
#     'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text':

#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 222},
#         'duration': {'text': '3 mins', 'value': 167},
#         'end_location': {'lat': 53.3456369, 'lng': -6.2624936},
#         'html_instructions': 'Turn <b>left</b> onto <b>Fleet St</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'mbrdIxnee@@^FlBHlCLrFBrB?R'},
#         'start_location': {'lat': 53.34583259999999,
#          'lng': -6.259165899999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 119},
#         'duration': {'text': '1 min', 'value': 85},
#         'end_location': {'lat': 53.3455333, 'lng': -6.264282},
#         'html_instructions': 'Continue onto <b>Temple Bar</b>',
#         'polyline': {'points': 'gardIpcfe@BhAFnBHjD'},
#         'start_location': {'lat': 53.3456369, 'lng': -6.2624936},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 226},
#         'duration': {'text': '3 mins', 'value': 172},
#         'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999},
#         'html_instructions': 'Continue onto <b>Essex St E</b>',
#         'polyline': {'points': 'q`rdIvnfe@V~BL|A?HBHBHX`@XrD@RFlAHjA'},
#         'start_location': {'lat': 53.3455333, 'lng': -6.264282},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENGM[j@iAhBy@jA]\\s@l@_@PU?u@j@qCjB}B|As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEuAvDkBnDqBrCsAlBsDzFyDlGiAfBy@xAKRu@t@GFQHQXw@bAKNsC`EkArBSX{BtDYj@Y~@Q~BI^Yr@u@vAs@tAeBbCg@p@m@t@yAvBkCzDgBhCiC~D}BxCaB`CmAlB]bAk@pBy@xCsArEu@rBMj@[dAMn@g@|E[nBYjA_@dAk@fAo@|@[\\wA`A]NoAj@mAt@SASNOJkArAeBjBaAfAmCxC}B|BuAzA?H}B`Cu@jAWLOAuJgH[Qa@@_@b@Q^[zBsB|KYLkA[cBWoNmCw@~FIV[VWAg@Mu@@QBkAz@aBwAs@CcADM??d@?Y[@M?@^PzFPfJB|APzGd@|EBR\\j@ZfEPxC'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
# Shows all different trip options worked out by google
route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]    
route_keys
# Out:
# [dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])]

# %%
a["routes"][0]["bounds"]
# Out:
# {'northeast': {'lat': 53.3449392, 'lng': -6.2245418},
#  'southwest': {'lat': 53.3051888, 'lng': -6.267477299999999}}

# %%
# Shows all the steps in a trip
for i, val in enumerate(a["routes"][0]["legs"][0]["steps"]):
    print(i)
    print(val)
# Out:
# 0
# {'distance': {'text': '0.5 km', 'value': 477}, 'duration': {'text': '6 mins', 'value': 346}, 'end_location': {'lat': 53.3082138, 'lng': -6.2303126}, 'html_instructions': 'Walk to Belfield, University College of Dublin UCD', 'polyline': {'points': 'yvjdIjv~d@LD@?LDKfBAF?@@B?BB@B@ZDN@D@BB?@VFCp@AfAFXA@?@?@A??@?@?@?@?@?@?@?@@??@?@@??@?@CVIf@EjAKxB?PGbBChAAh@AVA^?p@A^?dA?lAA?A?A??@A?A@A@A@?@A@?@A@?@?@?@A??@?@?@?@?B[@UC'}, 'start_location': {'lat': 53.3081298, 'lng': -6.2245418}, 'steps': [{'distance': {'text': '8 m', 'value': 8}, 'duration': {'text': '1 min', 'value': 6}, 'end_location': {'lat': 53.3080577, 'lng': -6.224570399999999}, 'html_instructions': 'Head <b>south</b>', 'polyline': {'points': 'yvjdIjv~d@LD'}, 'start_location': {'lat': 53.3081298, 'lng': -6.2245418}, 'travel_mode': 'WALKING'}, {'building_level': {'number': 2}, 'distance': {'text': '8 m', 'value': 8}, 'duration': {'text': '1 min', 'value': 6}, 'end_location': {'lat': 53.3079832, 'lng': -6.224598599999999}, 'html_instructions': 'Walk for 8&nbsp;m', 'polyline': {'points': 'kvjdIpv~d@@?LD'}, 'start_location': {'lat': 53.3080577, 'lng': -6.224570399999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '77 m', 'value': 77}, 'duration': {'text': '1 min', 'value': 55}, 'end_location': {'lat': 53.3077288, 'lng': -6.2253066}, 'html_instructions': 'Head <b>west</b>', 'polyline': {'points': '{ujdIvv~d@KfBAF?@@B?BB@B@ZDN@D@BB?@'}, 'start_location': {'lat': 53.3079832, 'lng': -6.224598599999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '14 m', 'value': 14}, 'duration': {'text': '1 min', 'value': 11}, 'end_location': {'lat': 53.30760900000001, 'lng': -6.2253491}, 'html_instructions': 'Slight <b>left</b>', 'maneuver': 'turn-slight-left', 'polyline': {'points': 'itjdId{~d@VF'}, 'start_location': {'lat': 53.3077288, 'lng': -6.2253066}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 324}, 'duration': {'text': '4 mins', 'value': 234}, 'end_location': {'lat': 53.3078572, 'lng': -6.230148799999999}, 'html_instructions': 'Turn <b>right</b><div style="font-size:0.9em">Go through 1 roundabout</div>', 'maneuver': 'turn-right', 'polyline': {'points': 'qsjdIl{~d@Cp@AfAFXA@?@?@A??@?@?@?@?@?@?@?@@??@?@@??@?@CVIf@EjAKxB?PGbBChAAh@AVA^?p@A^?dA?lA'}, 'start_location': {'lat': 53.30760900000001, 'lng': -6.2253491}, 'travel_mode': 'WALKING'}, {'distance': {'text': '46 m', 'value': 46}, 'duration': {'text': '1 min', 'value': 34}, '
great George's Street"}, 'arrival_time': {'text': '5:33pm', 'time_zone': 'Europe/Dublin', 'value': 1562603595}, 'departure_stop': {'location': {'lat': 53.3082019, 'lng': -6.2300505}, 'name': 'Belfield, University College of Dublin UCD'}, 'departure_time': {'text': '5:05pm', 'time_zone': 'Europe/Dublin', 'value': 1562601900}, 'headsign': 'Coast Road', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '142', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 20}, 'travel_mode': 'TRANSIT'}
# 2
# {'distance': {'text': '0.5 km', 'value': 480}, 'duration': {'text': '6 mins', 'value': 339}, 'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999}, 'html_instructions': 'Walk to Temple Bar, Dublin, Ireland', 'polyline': {'points': 'ylqdIrpfe@CAKGSGMAGAICE?u@Gq@?C?u@@}@F_A??dA?dB?xB?n@?X@^BfADnAyBd@i@L'}, 'start_location': {'lat': 53.3423695, 'lng': -6.2645801}, 'steps': [{'distance': {'text': '0.2 km', 'value': 203}, 'duration': {'text': '2 mins', 'value': 141}, 'end_location': {'lat': 53.34418179999999, 'lng': -6.264465}, 'html_instructions': "Head <b>north</b> on <b>South Great George's Street</b>/<b>R114</b> toward <b>George's Street Arcade</b>", 'polyline': {'points': 'ylqdIrpfe@CAKGSGMAGAICE?u@Gq@?C?u@@}@F_A?'}, 'start_location': {'lat': 53.3423695, 'lng': -6.2645801}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.2 km', 'value': 184}, 'duration': {'text': '2 mins', 'value': 135}, 'end_location': {'lat': 53.3441189, 'lng': -6.267224000000001}, 'html_instructions': 'Turn <b>left</b> onto <b>Dame St</b>/<b>R137</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'cxqdIzofe@?dA?dB?xB?n@?X@^BfADnA'}, 'start_location': {'lat': 53.34418179999999, 'lng': -6.264465}, 'travel_mode': 'WALKING'}, {'distance': {'text': '93 m', 'value': 93}, 'duration': {'text': '1 min', 'value': 63}, 'end_location': {'lat': 53.3449392, 'lng': -6.267477299999999}, 'html_instructions': 'Turn <b>right</b> onto <b>Parliament St</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'wwqdIbage@yBd@i@L'}, 'start_location': {'lat': 53.3441189, 'lng': -6.267224000000001}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}

# %%
# Shows only steps with bus 
print(a["routes"][0]["legs"][0]["steps"][1]["transit_details"])
# Out:
# {'arrival_stop': {'location': {'lat': 53.3423819, 'lng': -6.2646646}, 'name': "Dublin City South, South Great George's Street"}, 'arrival_time': {'text': '5:33pm', 'time_zone': 'Europe/Dublin', 'value': 1562603595}, 'departure_stop': {'location': {'lat': 53.3082019, 'lng': -6.2300505}, 'name': 'Belfield, University College of Dublin UCD'}, 'departure_time': {'text': '5:05pm', 'time_zone': 'Europe/Dublin', 'value': 1562601900}, 'headsign': 'Coast Road', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '142', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 20}

# %%
print("vehicle: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["vehicle"]["type"])
print()
print("dep stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"])
print()
print("arr stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"])
print()
print("headsign: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["headsign"])
print()
print("route name: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["short_name"])
print()
print("num_stops: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["num_stops"])
print()
print("dep time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
print()
print("arri time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
print()
arr = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
dep = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
tot = datetime.timedelta(seconds=(arr - dep))
print("total time: ", tot)
# Out:
# vehicle:  BUS
#
# dep stop:  {'location': {'lat': 53.3082019, 'lng': -6.2300505}, 'name': 'Belfield, University College of Dublin UCD'}
#
# arr stop:  Dublin City South, South Great George's Street
#
# headsign:  Coast Road
#
# route name:  142
#
# num_stops:  20
#
# dep time:  1562601900
#
# arri time:  1562603595
#
# total time:  0:28:15

# %%
for i in range(len(route_keys)):
    for j in range(len(a["routes"][i]["legs"][0]["steps"])):
    
        if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
            print("Vehicle: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"])
            
            print("dep stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"])
            
            print("arr stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"])
            
            print("headsign: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"])
                  
            print("route name: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"])
                  
            print("num_stops: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["num_stops"])
            
            arr = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_time"]["value"])
            dep = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_time"]["value"])
            tot = datetime.timedelta(seconds=(arr - dep))
            print("totalbus trip time: ", tot)
                  
            print("step number", j)
            print("option number:", i)
            print()
            
    print("-----------------------------------------------------")
    print()
# Out:
# Vehicle:  BUS
# dep stop:  Belfield, University College of Dublin UCD
# arr stop:  Dublin City South, South Great George's Street
# headsign:  Coast Road
# route name:  142
# num_stops:  20
# totalbus trip time:  0:28:15
# step number 1
# option number: 0
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Temple Bar, Wellington Quay
# headsign:  Maynooth
# route name:  67x
# num_stops:  23
# totalbus trip time:  0:41:13
# step number 1
# option number: 1
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Dublin City South, Dawson Street
# headsign:  Heuston Station
# route name:  145
# num_stops:  15
# totalbus trip time:  0:21:18
# step number 1
# option number: 2
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Dublin City South, Westmoreland Street
# headsign:  Phoenix Pk
# route name:  46a
# num_stops:  16
# totalbus trip time:  0:27:14
# step number 1
# option number: 3
#
# -----------------------------------------------------

# %%
query1 = """SELECT stop_lat,stop_lon,stop_id,stop_name 
        FROM research.stops 
        WHERE stop_name LIKE %s or stop_name LIKE %s"""


query2 = """SELECT distinct research.stop_times.bus_number  
        FROM research.stop_times 
        WHERE research.stop_times.bus_number=%s and research.stop_times.bus_stop_number=%s and research.stop_times.headsign=%s"""


query3 = """SELECT research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.trips.direction_id, research.stop_times.headsign 
        FROM research.stop_times, research.trips 
        WHERE stop_times.trip_id = trips.trip_id and stop_times.headsign = %s and stop_times.bus_number = %s and (bus_stop_number = %s or bus_stop_number = %s)"""


query4 = """SELECT research.stops.stop_lat, research.stops.stop_lon, research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.stop_times.headsign, research.stop_times.bus_number 
        FROM research.stop_times, research.stops
        WHERE bus_number = %s and headsign = %s and (stop_sequence between %s AND %s)
        LIMIT %s
        """

# This are stop names not addresses:

# "Dublin (UCD Stillorgan Rd Flyover)"
# "Dublin City South, Westmoreland Street"

# "Marino, East South B. Sub Station"
# "Dublin City South, Hawkin's Street"

stopA = "Dublin (UCD Stillorgan Rd Flyover)"
stopB = "Dublin City South, Westmoreland Street"

# %%
def db_query(query, stopA, stopB):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)

    cur = con.cursor()
    cur.execute(query, (stopA, stopB),)
    data = cur.fetchall()
    cur.close()
    return data

# %%
# b = db_query(query1, stopA, stopB)
# b

# %%
def db_query2(query, bus_no, stop_no, head_sign):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)

    cur = con.cursor()
    cur.execute(query, (bus_no, stop_no, head_sign),)
    data = list(cur.fetchall())

    if len(data) > 0:
        data.pop()
        data.append(bus_no)
        data.append(head_sign)
    cur.close()
    return data

# %%
def start_end(b, bus_no, head_sign):
    c = []

    for i in b:
        z = db_query2(query2, bus_no, i[2], head_sign)
        if(len(z)!=0):
            z.append(i[0])
            z.append(i[1])
            z.append(i[2])
            z.append(i[3])
            c.append(z)
    return c

# d = start_end(b)
# d

# %%
def db_query3(query, head_sign, bus_no, stop_noA, stop_noB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    cur = con.cursor()
    cur.execute(query, (head_sign, bus_no, stop_noA, stop_noB),)
    cur.close()
    return cur.fetchall()

# %%
# e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])
# e

# %%
def db_query4(query, bus_no, head_sign, seqA, seqB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
    limit = seqB - seqA + 1
    cur = con.cursor()
    cur.execute(query, (bus_no, head_sign, seqA, seqB, limit),)
    cur.close()
    return cur.fetchall()

# %%
# f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
# f

# %%
def fin(a):
    
    route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]
    
    for i in range(len(route_keys)):
        for j in range(len(a["routes"][i]["legs"][0]["steps"])):
            if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
                
                dep_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"]
                arr_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"]
                bus_no = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"]
                head_sign = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"]
                
                b = db_query(query1, dep_stop, arr_stop)
                d = start_end(b, bus_no, head_sign)
                e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])    
                f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
                
                print(f)
                print("step: ", j)
        print("option: ", i)
        print("*****************************************************************")
        
fin(a)
# Out:
# (('53.2480439849', '-6.12315403365', '8250DB000877', 1, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8250DB000876', 2, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8250DB003011', 3, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8250DB002896', 4, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8250DB002897', 5, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001062', 6, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001063', 7, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001064', 8, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001065', 9, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001066', 10, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001067', 11, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001068', 12, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001069', 13, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001070', 14, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001071', 15, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB004528', 16, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001072', 17, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB007577', 18, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001353', 19, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB001354', 20, 'Coast Road', '142'), ('53.2480439849', '-6.12315403365', '8220DB007578', 21, 'Coast Road', '142'))
# step:  1
# option:  0
# *****************************************************************
# (('53.2480439849', '-6.12315403365', '8250DB000768', 2, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000769', 3, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000770', 4, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000771', 5, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000772', 6, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000773', 7, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000774', 8, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000775', 9, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000776', 10, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000777', 11, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000779', 12, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000780', 13, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000781', 14, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000782', 15, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000783', 16, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000784', 17, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000785', 18, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000786', 19, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000791', 20, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB007585', 21, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB007587', 22, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220DB000345', 23, 'Maynooth', '67X'), ('53.2480439849', '-6.12315403365', '8220D