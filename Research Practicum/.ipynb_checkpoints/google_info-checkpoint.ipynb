# %%
import requests, json, datetime, pymysql, sys

# %%
def get_direct_goo():
    
#     "Fairview, County Dublin, Ireland"
#     "Killiney, County Dublin, Ireland"

#     "Heuston Station, Saint John's Road West, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

#     "University College Dublin, Belfield, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

    postA = "University College Dublin, Belfield, Dublin, Ireland"
    postB = "Dublin Airport, County Dublin, Ireland"

    api_key = 'AIzaSyBi-bH5_sngxNibrgygRZDhmAv2fK5hzus'
    url ='https://maps.googleapis.com/maps/api/directions/json?alternatives=true&transit_mode=bus&'

    req = requests.get(url + 'origin=' + postA +'&destination=' + postB
                     +'&sensor='+"false"+'&mode='+"transit"+'&key=' + api_key)

    return req.json()

a = get_direct_goo()

# %%
a.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
# Everything together
a["routes"]
# Out:
# [{'bounds': {'northeast': {'lat': 53.426812, 'lng': -6.2185592},
#    'southwest': {'lat': 53.3079626, 'lng': -6.2611548}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '6:54pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562694888},
#     'departure_time': {'text': '6:06pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562691970},
#     'distance': {'text': '18.1 km', 'value': 18099},
#     'duration': {'text': '49 mins', 'value': 2918},
#     'end_address': 'Corballis, Dublin Airport, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '64 m', 'value': 64},
#         'duration': {'text': '1 min', 'value': 43},
#         'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#         'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#         'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '17.5 km', 'value': 17509},
#       'duration': {'text': '41 mins', 'value': 2460},
#       'end_location': {'lat': 53.426778, 'lng': -6.2395461},
#       'html_instructions': 'Bus towards Dublin Airport',
#       'polyline': {'points': 'y~jdI|r}d@k@}@{@vBc@z@GL[f@a@h@SVUTUR]XKHi@`@IFk@^yA`AcAr@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZEAELa@fAIUHSX}@n@{BdAwEp@yBp@_BLRk@rAY|@sCxKELmA~CuA|BmJpNaIhMUNkBtCy@~@@B{AvBEFk@x@Yj@q@fAKLGJw@nA[h@g@z@OXIPIROj@Q~BI^O^IRMXOTCFS^]p@Ub@{ArBINGFMRQTQT[^c@l@u@hAYb@aBbCGHGHm@z@W`@QTOTKRe@v@A@uApBIJoA`Bc@j@m@x@s@fAi@t@c@v@CHITELITK\\GNW`A?@Mf@Wx@EPMd@Od@YdASr@Ur@KZINCJ[z@AJ?BABIVK\\Of@Kb@AJG`@_@zDM~@Mn@On@K`@]~@U`@Ud@U\\Y^MNMLa@Xu@f@SHEBC@QFUJGD_@PaAn@KDSASNIFEBIFaAjAc@d@g@j@IHONc@b@sBdCw@v@QPe@d@[\\i@f@g@h@m@p@OPWXCDEDkAnA_@h@KVEHEFIX[Si@_@KGy@i@YScAs@SQwB{A[Y[YGACAE?G?MDGBED?@EFCFGVEXADAFCEYlBWSg@a@cEaCiCsAgGgC`@uDVgBDmAQoBg@yB@u@PcAFy@OWuEgCwCyAU@YVGVgBbNE\\mB`Qe@rDU~BKfDz@lDZt@^|@b@j@pAbAjA{@PCt@Af@LV@ZWHWfBkM@E@@Ly@D[XwBDa@h@cEf@uDP_B@CBUBg@@S@e@AKAECKM_@Om@GWKc@CM?G?AAG?K@OBYD]LmABYSKYOgCsAoBcAMIEA[OGCQKS?I@G@IDGFILG`@OjAm@rEKr@Ej@MlAE^Q~AQxAi@tFE^M|@@RALANEPETAHQdAGVUhA?BE\\ANCXCj@AZ?t@AJ?F?H@H?JBL@JFZNp@Lh@Lh@?L?H@N@T?RCz@}@?W@M?w@Ay@?y@C]CS@K@C@IBc@R]NMFKFU@}Br@IBGBG@YLI@mA`@SFkC|@{Af@aEtAmA`@@EcfAaPSEmmKqrBD_A'},
#       'start_location': {'lat': 53.3094098, 'lng': -6.2188692},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.426778,
#          'lng': -6.2395461},
#         'name': 'Dublin Airport'},
#        'arrival_time': {'text': '6:53pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562694780},
#        'departure_stop': {'location': {'lat': 53.3094098, 'lng': -6.2188692},
#         'name': 'Dublin (UCD Stillorgan Rd Flyover)'},
#        'departure_time': {'text': '6:12pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562692320},
#        'headsign': 'Dublin Airport',
#        'line': {'agencies': [{'name': 'Aircoach',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '700',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 13},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 107},
#       'duration': {'text': '2 mins', 'value': 108},
#       'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#       'html_instructions': 'Walk to Corballis, Dublin Airport, Co. Dublin, Ireland',
#       'polyline': {'points': 'k|aeIbtae@@GHHRN`@NL_@Ns@L_AD]'},
#       'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#       'steps': [{'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 2},
#         'end_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'html_instructions': 'Head <b>southeast</b>',
#         'polyline': {'points': 'k|aeIbtae@@G'},
#         'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '6 m', 'value': 6},
#         'duration': {'text': '1 min', 'value': 5},
#         'end_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'i|aeIzsae@HH'},
#         'start_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '46 m', 'value': 46},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'html_instructions': 'Walk for 46&nbsp;m',
#         'polyline': {'points': '_|aeIdtae@RN`@NL_@'},
#         'start_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '19 m', 'value': 19},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'html_instructions': 'Take the escalator <b>down</b> to 0',
#         'polyline': {'points': '{yaeIdtae@Ns@'},
#         'start_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '33 m', 'value': 33},
#         'duration': {'text': '1 min', 'value': 28},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Walk for 33&nbsp;m',
#         'polyline': {'points': 'kyaeIprae@L_AD]'},
#         'start_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Head<div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'wxaeIroae@'},
#         'start_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENk@}@{@vBc@z@c@t@u@`AuAlAyDjC_C~As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEWv@EAELa@fAIUb@qAn@{BdAwEp@yBp@_BLRk@rAmDvMsAlDuA|BmJpNaIhMUNkBtCy@~@yAzBq@`AkArBSXkCnESd@Oj@Q~BY~@Wl@eAnBUb@{ArBQVmA~AuE~GuApBsAvBqD`FqAdB}A|Bg@`AOb@u@dCwBzHo@jB[z@AJAFUt@[jAIl@m@zF]~Ai@`Bk@fAo@|@[\\wA`A]NoAj@mAt@SASNOJkArAeBjBwChDiAhAsCtCyAbBqAtAk@`AKPIX[Su@g@sA}@wAeAsCuBc@[IAUDMHQh@G^AFCEYlBWSg@a@cEaCiCsAgGgC`@uDVgBDmAQoBg@yB@u@PcAFy@OWuEgCwCyAU@YVGVmB`OmB`Qe@rDU~BKfDz@lDZt@^|@b@j@pAbAjA{@PCt@Af@LV@ZWHWhBqM@@Ly@^sChB{NJuA?q@EQq@iCE_@@[Hw@PgBSK_HqD{@a@]@QFQTWlBy@fGSxBsAnMS|A?`@O`Ao@jDOrBCdBDl@f@bCLh@?L@X@h@Cz@}@?e@@qBAwAG_@BoAh@YNU@}Br@QFa@NwFhB}G|BmA`@@EwfAgPmmKqrBD_A@I\\X`@NL_@Ns@R}A'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.426812, 'lng': -6.2185592},
#    'southwest': {'lat': 53.3079626, 'lng': -6.2611548}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '7:09pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562695788},
#     'departure_time': {'text': '6:21pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562692870},
#     'distance': {'text': '18.1 km', 'value': 18099},
#     'duration': {'text': '49 mins', 'value': 2918},
#     'end_address': 'Corballis, Dublin Airport, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '64 m', 'value': 64},
#         'duration': {'text': '1 min', 'value': 43},
#         'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#         'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#         'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '17.5 km', 'value': 17509},
#       'duration': {'text': '41 mins', 'value': 2460},
#       'end_location': {'lat': 53.426778, 'lng': -6.2395461},
#       'html_instructions': 'Bus towards Dublin Airport',
#       'polyline': {'points': 'y~jdI|r}d@k@}@{@vBc@z@GL[f@a@h@SVUTUR]XKHi@`@IFk@^yA`AcAr@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZEAELa@fAIUHSX}@n@{BdAwEp@yBp@_BLRk@rAY|@sCxKELmA~CuA|BmJpNaIhMUNkBtCy@~@@B{AvBEFk@x@Yj@q@fAKLGJw@nA[h@g@z@OXIPIROj@Q~BI^O^IRMXOTCFS^]p@Ub@{ArBINGFMRQTQT[^c@l@u@hAYb@aBbCGHGHm@z@W`@QTOTKRe@v@A@uApBIJoA`Bc@j@m@x@s@fAi@t@c@v@CHITELITK\\GNW`A?@Mf@Wx@EPMd@Od@YdASr@Ur@KZINCJ[z@AJ?BABIVK\\Of@Kb@AJG`@_@zDM~@Mn@On@K`@]~@U`@Ud@U\\Y^MNMLa@Xu@f@SHEBC@QFUJGD_@PaAn@KDSASNIFEBIFaAjAc@d@g@j@IHONc@b@sBdCw@v@QPe@d@[\\i@f@g@h@m@p@OPWXCDEDkAnA_@h@KVEHEFIX[Si@_@KGy@i@YScAs@SQwB{A[Y[YGACAE?G?MDGBED?@EFCFGVEXADAFCEYlBWSg@a@cEaCiCsAgGgC`@uDVgBDmAQoBg@yB@u@PcAFy@OWuEgCwCyAU@YVGVgBbNE\\mB`Qe@rDU~BKfDz@lDZt@^|@b@j@pAbAjA{@PCt@Af@LV@ZWHWfBkM@E@@Ly@D[XwBDa@h@cEf@uDP_B@CBUBg@@S@e@AKAECKM_@Om@GWKc@CM?G?AAG?K@OBYD]LmABYSKYOgCsAoBcAMIEA[OGCQKS?I@G@IDGFILG`@OjAm@rEKr@Ej@MlAE^Q~AQxAi@tFE^M|@@RALANEPETAHQdAGVUhA?BE\\ANCXCj@AZ?t@AJ?F?H@H?JBL@JFZNp@Lh@Lh@?L?H@N@T?RCz@}@?W@M?w@Ay@?y@C]CS@K@C@IBc@R]NMFKFU@}Br@IBGBG@YLI@mA`@SFkC|@{Af@aEtAmA`@@EcfAaPSEmmKqrBD_A'},
#       'start_location': {'lat': 53.3094098, 'lng': -6.2188692},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.426778,
#          'lng': -6.2395461},
#         'name': 'Dublin Airport'},
#        'arrival_time': {'text': '7:08pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562695680},
#        'departure_stop': {'location': {'lat': 53.3094098, 'lng': -6.2188692},
#         'name': 'Dublin (UCD Stillorgan Rd Flyover)'},
#        'departure_time': {'text': '6:27pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562693220},
#        'headsign': 'Dublin Airport',
#        'line': {'agencies': [{'name': 'Aircoach',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '700',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 13},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 107},
#       'duration': {'text': '2 mins', 'value': 108},
#       'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#       'html_instructions': 'Walk to Corballis, Dublin Airport, Co. Dublin, Ireland',
#       'polyline': {'points': 'k|aeIbtae@@GHHRN`@NL_@Ns@L_AD]'},
#       'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#       'steps': [{'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 2},
#         'end_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'html_instructions': 'Head <b>southeast</b>',
#         'polyline': {'points': 'k|aeIbtae@@G'},
#         'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '6 m', 'value': 6},
#         'duration': {'text': '1 min', 'value': 5},
#         'end_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'i|aeIzsae@HH'},
#         'start_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '46 m', 'value': 46},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'html_instructions': 'Walk for 46&nbsp;m',
#         'polyline': {'points': '_|aeIdtae@RN`@NL_@'},
#         'start_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '19 m', 'value': 19},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'html_instructions': 'Take the escalator <b>down</b> to 0',
#         'polyline': {'points': '{yaeIdtae@Ns@'},
#         'start_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '33 m', 'value': 33},
#         'duration': {'text': '1 min', 'value': 28},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Walk for 33&nbsp;m',
#         'polyline': {'points': 'kyaeIprae@L_AD]'},
#         'start_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Head<div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'wxaeIroae@'},
#         'start_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENk@}@{@vBc@z@c@t@u@`AuAlAyDjC_C~As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEWv@EAELa@fAIUb@qAn@{BdAwEp@yBp@_BLRk@rAmDvMsAlDuA|BmJpNaIhMUNkBtCy@~@yAzBq@`AkArBSXkCnESd@Oj@Q~BY~@Wl@eAnBUb@{ArBQVmA~AuE~GuApBsAvBqD`FqAdB}A|Bg@`AOb@u@dCwBzHo@jB[z@AJAFUt@[jAIl@m@zF]~Ai@`Bk@fAo@|@[\\wA`A]NoAj@mAt@SASNOJkArAeBjBwChDiAhAsCtCyAbBqAtAk@`AKPIX[Su@g@sA}@wAeAsCuBc@[IAUDMHQh@G^AFCEYlBWSg@a@cEaCiCsAgGgC`@uDVgBDmAQoBg@yB@u@PcAFy@OWuEgCwCyAU@YVGVmB`OmB`Qe@rDU~BKfDz@lDZt@^|@b@j@pAbAjA{@PCt@Af@LV@ZWHWhBqM@@Ly@^sChB{NJuA?q@EQq@iCE_@@[Hw@PgBSK_HqD{@a@]@QFQTWlBy@fGSxBsAnMS|A?`@O`Ao@jDOrBCdBDl@f@bCLh@?L@X@h@Cz@}@?e@@qBAwAG_@BoAh@YNU@}Br@QFa@NwFhB}G|BmA`@@EwfAgPmmKqrBD_A@I\\X`@NL_@Ns@R}A'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.4282036, 'lng': -6.2187873},
#    'southwest': {'lat': 53.3079626, 'lng': -6.2455956}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '7:03pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562695428},
#     'departure_time': {'text': '6:06pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562691988},
#     'distance': {'text': '18.5 km', 'value': 18491},
#     'duration': {'text': '57 mins', 'value': 3440},
#     'end_address': 'Corballis, Dublin Airport, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '0.5 km', 'value': 483},
#       'duration': {'text': '6 mins', 'value': 350},
#       'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#       'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#       'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'html_instructions': 'Head',
#         'polyline': {'points': 'wujdInt~d@'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '68 m', 'value': 68},
#         'duration': {'text': '1 min', 'value': 54},
#         'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'html_instructions': 'Walk for 68&nbsp;m',
#         'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 32},
#         'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'html_instructions': 'Head <b>northeast</b>',
#         'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#         'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'html_instructions': 'Slight <b>left</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#         'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '37 m', 'value': 37},
#         'duration': {'text': '1 min', 'value': 24},
#         'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#         'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#         'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '93 m', 'value': 93},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#         'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '87 m', 'value': 87},
#         'duration': {'text': '1 min', 'value': 63},
#         'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#         'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '15 m', 'value': 15},
#         'duration': {'text': '1 min', 'value': 13},
#         'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 's}jdIxx}d@HYDK'},
#         'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '64 m', 'value': 64},
#         'duration': {'text': '1 min', 'value': 43},
#         'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#         'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#         'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '3.5 km', 'value': 3468},
#       'duration': {'text': '11 mins', 'value': 638},
#       'end_location': {'lat': 53.3335836, 'lng': -6.244585799999999},
#       'html_instructions': 'Bus towards Ongar',
#       'polyline': {'points': 'y~jdI|r}d@GMMTMTi@~@_@h@y@jA]\\YXYRKHSFM@GAKHi@`@IFk@^yA`AA@aAp@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZi@xASd@Uf@Uf@o@dAOXm@z@UX[b@QXs@dA_@f@yAxByA`CmB`DGJy@pAILSZg@v@IJCF[h@]n@KRu@t@A@EDQHQXg@p@OPKNCB}AzBEFk@x@Yj@q@fAKLGJw@nA[h@EFa@r@OXIPIROj@Q~BI^O^IRMXOTCFS^]p@Ub@{ArBINGFMRGHIJQT[^c@l@u@hAYb@aBbCGHGHm@z@W`@QTOTKRe@v@A@uApBIJILeArAc@j@m@x@s@fAi@t@c@v@CHITELITK\\GNW`A?@Mf@uAy@SGQGk@UuHcCaA]i@Os@WcDgAIAuAe@SGQEiA_@CJc@bBi@dBITHP'},
#       'start_location': {'lat': 53.3094098, 'lng': -6.2188692},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3335836,
#          'lng': -6.244585799999999},
#         'name': 'Dublin City South, Upper Baggot Street'},
#        'arrival_time': {'text': '6:22pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562692976},
#        'departure_stop': {'location': {'lat': 53.3094098, 'lng': -6.2188692},
#         'name': 'Dublin (UCD Stillorgan Rd Flyover)'},
#        'departure_time': {'text': '6:12pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562692338},
#        'headsign': 'Ongar',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '39a',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 13},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.7 km', 'value': 661},
#       'duration': {'text': '8 mins', 'value': 485},
#       'end_location': {'lat': 53.3366261, 'lng': -6.238830500000001},
#       'html_instructions': 'Walk to Dublin City South, Northumberland Road',
#       'polyline': {'points': 'evodIbsbe@uAlCi@{C[yAq@iDc@sBc@wBq@cDQcAI_@G[Ie@aAoEa@qB]mB{@vAc@p@'},
#       'start_location': {'lat': 53.3336334, 'lng': -6.244502199999999},
#       'steps': [{'distance': {'text': '67 m', 'value': 67},
#         'duration': {'text': '1 min', 'value': 53},
#         'end_location': {'lat': 53.3340579, 'lng': -6.245211299999999},
#         'html_instructions': 'Head <b>northwest</b> on <b>Baggot Street Upper</b>/<b>R816</b> toward <b>Mespil Rd</b>/<b>R111</b>',
#         'polyline': {'points': 'evodIbsbe@uAlC'},
#         'start_location': {'lat': 53.3336334, 'lng': -6.244502199999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.5 km', 'value': 524},
#         'duration': {'text': '6 mins', 'value': 376},
#         'end_location': {'lat': 53.3361516, 'lng': -6.238141499999999},
#         'html_instructions': 'Turn <b>right</b> onto <b>Haddington Rd</b>/<b>R111</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '{xodIpwbe@i@{C[yAq@iDc@sBc@wBq@cDQcAI_@G[Ie@aAoEa@qB]mB'},
#         'start_location': {'lat': 53.3340579, 'lng': -6.245211299999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '70 m', 'value': 70},
#         'duration': {'text': '1 min', 'value': 56},
#         'end_location': {'lat': 53.3366261, 'lng': -6.238830500000001},
#         'html_instructions': 'Turn <b>left</b> onto <b>Northumberland Rd</b>/<b>R118</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': '}epdIjkae@{@vAc@p@'},
#         'start_location': {'lat': 53.3361516, 'lng': -6.238141499999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '13.8 km', 'value': 13772},
#       'duration': {'text': '22 mins', 'value': 1320},
#       'end_location': {'lat': 53.426778, 'lng': -6.2395461},
#       'html_instructions': 'Bus towards Dublin Airport',
#       'polyline': {'points': '}hpdItoae@?A{B~DkAlCcAvEg@c@g@m@w@sAi@oAa@o@_ChI_JaAwIkAkE_@yCc@?@aC[A?u@M_@IKHIDADAD?DAPGbBCLCLGHCBA@C@A@C@E?I?G?g@Ew@Iu@Iq@GICQC?WH{BBu@@M?QVaLBm@FcC@i@@c@FiBF}B@]DiBBq@FqBRsH@m@Bg@P{EJmD@WHyBF{B@_@@K?QBq@?E@C?I?I?S?OAMAK?KCMA?A?A?A?AAA?AAA??AAAAA?AAA?A?AA??A?A?A?AAA?A?A?A?A?A?A?A?AMIMIMESE_@CMAG?OCQCwAMC?iBSeA?o@HkBOo@SgFkDmC{AuAkAc@k@wB{Da@m@c@c@_@UeASeAFe@R[Tc@j@a@t@[~@i@jC}ArJeChKq@pBoDtG_CtD_DrDyBbBwAx@sB`AuBl@eARgCT}Ih@wDpBiKjCmLlIgDlBeFrMy@hBeB|CcC`DwAxAeDhCkB~@mAf@cDr@cBPkBFmGOmLg@oL{@}JqA_r@sKyHmByAg@wDaBkDkBsIgGyOiOyNuNuTeTiEyDyBgBgHaFmGwD{C}AmKoEwNuGyIoDqg@}T}Dy@e@AmBZeAn@}@bAqAhC{@~CYrBo@vOg@fXFpAb@lBBt@Et@c@fBSjBCzAJfBZvA\\x@X^rHjGPd@X`@Tl@Ld@JjA@l@Cj@WnBe@tA_@`BiCdMTR'},
#       'start_location': {'lat': 53.3366266, 'lng': -6.2388295},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.426778,
#          'lng': -6.2395461},
#         'name': 'Dublin Airport'},
#        'arrival_time': {'text': '7:02pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562695320},
#        'departure_stop': {'location': {'lat': 53.3366266, 'lng': -6.2388295},
#         'name': 'Dublin City South, Northumberland Road'},
#        'departure_time': {'text': '6:40pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562694000},
#        'headsign': 'Dublin Airport',
#        'line': {'agencies': [{'name': 'Aircoach',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '703',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 3},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 107},
#       'duration': {'text': '2 mins', 'value': 108},
#       'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#       'html_instructions': 'Walk to Corballis, Dublin Airport, Co. Dublin, Ireland',
#       'polyline': {'points': 'k|aeIbtae@@GHHRN`@NL_@Ns@L_AD]'},
#       'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#       'steps': [{'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 2},
#         'end_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'html_instructions': 'Head <b>southeast</b>',
#         'polyline': {'points': 'k|aeIbtae@@G'},
#         'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '6 m', 'value': 6},
#         'duration': {'text': '1 min', 'value': 5},
#         'end_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'i|aeIzsae@HH'},
#         'start_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '46 m', 'value': 46},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'html_instructions': 'Walk for 46&nbsp;m',
#         'polyline': {'points': '_|aeIdtae@RN`@NL_@'},
#         'start_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '19 m', 'value': 19},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'html_instructions': 'Take the escalator <b>down</b> to 0',
#         'polyline': {'points': '{yaeIdtae@Ns@'},
#         'start_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '33 m', 'value': 33},
#         'duration': {'text': '1 min', 'value': 28},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Walk for 33&nbsp;m',
#         'polyline': {'points': 'kyaeIprae@L_AD]'},
#         'start_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Head<div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'wxaeIroae@'},
#         'start_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@AGq@w@I}AYsAQYMEQCI@Kg@EKSQG?AIMi@Mi@Gg@|@yC^kAq@mAm@cAQ]HYDKUmAWeABIEGENGM[j@iAhBy@jA]\\s@l@_@PU?u@j@qCjB}B|As@h@[Zw@x@e@r@gArBc@pAg@pBSbAgAbEuAvDkBnDqBrCsAlBsDzFyDlGiAfBy@xAKRu@t@GFQHQXw@bAKNsC`EkArBSX{BtDYj@Y~@Q~BI^Yr@u@vAs@tAeBbCg@p@m@t@yAvBkCzDgBhCiC~D}BxCaB`CmAlB]bAk@pBMf@uAy@e@OmMgEwE_B_Bg@e@MiA_@CJmAhEITHPIQuAlCi@{CmAcGgAkFuAcHkAuF_A_F_BfC{B~DkAlCcAvEg@c@g@m@w@sAi@oAa@o@_ChI_JaAwIkAkE_@yCc@?@cC[uAWUNCPItBGZQPUB}CY{@KQC?WLqD@_@d@}Rx@kZx@mWFaCCu@EMGAKOCWMK[Os@IUA}BUiBSeA?o@HkBOo@SgFkDmC{AuAkAc@k@wB{Da@m@c@c@_@UeASeAFe@R[Tc@j@a@t@[~@i@jC}ArJeChKq@pBoDtG_CtD_DrDyBbBwAx@sB`AuBl@eARgCT}Ih@wDpBiKjCmLlIgDlBeFrMy@hBeB|CcC`DwAxAeDhCkB~@mAf@cDr@cBPkBFmGOmLg@oL{@}JqA_r@sKyHmByAg@wDaBkDkBsIgGyOiOyNuNuTeTiEyDyBgBgHaFmGwD{C}AmKoEwNuGyIoDqg@}T}Dy@e@AmBZeAn@}@bAqAhC{@~CYrBo@vOg@fXFpAb@lBBt@Et@c@fBSjBCzAJfBZvA\\x@X^rHjGPd@X`@b@rAJjA@l@Cj@WnBe@tA_@`BiCdMTR@I\\X`@NL_@Ns@L_AD]'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.4282036, 'lng': -6.211231199999999},
#    'southwest': {'lat': 53.3079499, 'lng': -6.2445153}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '7:03pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562695428},
#     'departure_time': {'text': '6:09pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562692140},
#     'distance': {'text': '18.7 km', 'value': 18698},
#     'duration': {'text': '55 mins', 'value': 3288},
#     'end_address': 'Corballis, Dublin Airport, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#     'start_address': 'Belfield, Dublin, Ireland',
#     'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#     'steps': [{'distance': {'text': '2.0 km', 'value': 1988},
#       'duration': {'text': '24 mins', 'value': 1440},
#       'end_location': {'lat': 53.3181526, 'lng': -6.211231199999999},
#       'html_instructions': "Walk to Merrion, Saint Vincent's Hospital",
#       'polyline': {'points': 'wujdInt~d@@LCf@APOEUKIAeASo@OSxCM|Aw@SOCeAYQECAOnBIp@G`AMlBMGEEWc@[[kAjAmB~AGEGBEBGFEGEKk@kBuAmEOc@Sg@Q]Ym@GMEI_@y@c@gAYo@Ws@i@wAk@uAOYa@_AIUMUq@cBSe@GWgBcE_@w@}AeDg@mAkAoCk@mAUg@y@kBw@eBw@gBi@oAO]o@yAYm@Yo@IWESIs@Cc@Q}AMaAGe@I]?AK[EMMSb@kAXs@JYJ[DSPo@'},
#       'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#       'steps': [{'distance': {'text': '24 m', 'value': 24},
#         'duration': {'text': '1 min', 'value': 18},
#         'end_location': {'lat': 53.3079832, 'lng': -6.224598599999999},
#         'html_instructions': 'Head <b>west</b>',
#         'polyline': {'points': 'wujdInt~d@@LCf@AP'},
#         'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '8 m', 'value': 8},
#         'duration': {'text': '1 min', 'value': 7},
#         'end_location': {'lat': 53.3080577, 'lng': -6.224570399999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '{ujdIvv~d@OE'},
#         'start_location': {'lat': 53.3079832, 'lng': -6.224598599999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '58 m', 'value': 58},
#         'duration': {'text': '1 min', 'value': 44},
#         'end_location': {'lat': 53.308569, 'lng': -6.2243998},
#         'html_instructions': 'Walk for 58&nbsp;m',
#         'polyline': {'points': 'kvjdIpv~d@UKIAeAS'},
#         'start_location': {'lat': 53.3080577, 'lng': -6.224570399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '27 m', 'value': 27},
#         'duration': {'text': '1 min', 'value': 19},
#         'end_location': {'lat': 53.3088072, 'lng': -6.2243175},
#         'html_instructions': 'Head <b>north</b>',
#         'polyline': {'points': 'qyjdInu~d@o@O'},
#         'start_location': {'lat': 53.308569, 'lng': -6.2243998},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '85 m', 'value': 85},
#         'duration': {'text': '1 min', 'value': 61},
#         'end_location': {'lat': 53.3089777, 'lng': -6.2255631},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'a{jdI~t~d@SxCM|A'},
#         'start_location': {'lat': 53.3088072, 'lng': -6.2243175},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '94 m', 'value': 94},
#         'duration': {'text': '1 min', 'value': 70},
#         'end_location': {'lat': 53.30980229999999, 'lng': -6.2252711},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'c|jdIv|~d@w@SOCeAYQECA'},
#         'start_location': {'lat': 53.3089777, 'lng': -6.2255631},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 115},
#         'duration': {'text': '1 min', 'value': 82},
#         'end_location': {'lat': 53.3100355, 'lng': -6.2269634},
#         'html_instructions': 'Turn <b>left</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'gakdI|z~d@OnBIp@G`AMlB'},
#         'start_location': {'lat': 53.30980229999999, 'lng': -6.2252711},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '48 m', 'value': 48},
#         'duration': {'text': '1 min', 'value': 33},
#         'end_location': {'lat': 53.3103959, 'lng': -6.2265681},
#         'html_instructions': 'Turn <b>right</b> toward <b>Greenfield Park</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'wbkdIne_e@MGEEWc@[['},
#         'start_location': {'lat': 53.3100355, 'lng': -6.2269634},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 137},
#         'duration': {'text': '2 mins', 'value': 98},
#         'end_location': {'lat': 53.3114839, 'lng': -6.2274845},
#         'html_instructions': 'Turn <b>left</b> toward <b>Greenfield Park</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': '_ekdI`c_e@kAjAmB~AGEGBEBGF'},
#         'start_location': {'lat': 53.3103959, 'lng': -6.2265681},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.4 km', 'value': 391},
#         'duration': {'text': '5 mins', 'value': 276},
#         'end_location': {'lat': 53.3136849, 'lng': -6.2229136},
#         'html_instructions': 'Turn <b>right</b> onto <b>Greenfield Park</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'wkkdIvh_e@EGEKk@kBuAmEOc@Sg@Q]Ym@GMEI_@y@c@gAYo@Ws@i@wAk@uA'},
#         'start_location': {'lat': 53.3114839, 'lng': -6.2274845},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.9 km', 'value': 898},
#         'duration': {'text': '11 mins', 'value': 657},
#         'end_location': {'lat': 53.3187021, 'lng': -6.2124812},
#         'html_instructions': 'Continue onto <b>Nutley Ln</b>',
#         'polyline': {'points': 'oykdIdl~d@OYa@_AIUMUq@cBSe@GWgBcE_@w@}AeDg@mAkAoCk@mAUg@y@kBw@eBw@gBi@oAO]o@yAYm@Yo@IWESIs@Cc@Q}AMaAGe@I]?AK[EMMS'},
#         'start_location': {'lat': 53.3136849, 'lng': -6.2229136},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 103},
#         'duration': {'text': '1 min', 'value': 75},
#         'end_location': {'lat': 53.3181526, 'lng': -6.211231199999999},
#         'html_instructions': 'Turn <b>right</b> onto <b>Merrion Rd</b>/<b>R118</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '{xldI~j|d@b@kAXs@JYJ[DSPo@'},
#         'start_location': {'lat': 53.3187021, 'lng': -6.2124812},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '16.6 km', 'value': 16603},
#       'duration': {'text': '29 mins', 'value': 1740},
#       'end_location': {'lat': 53.426778, 'lng': -6.2395461},
#       'html_instructions': 'Bus towards Dublin Airport',
#       'polyline': {'points': 'euldIlc|d@GGQn@ERKZKXYr@c@jA_@x@]t@y@dBOVc@x@IH_@v@MVIPEH]t@a@v@KP_@v@e@`AGLi@bAc@x@gAbBGJa@j@]h@eAvAIJu@`AKLQTILoAlBi@`AcAtBy@bBs@vAkAbCo@lASb@Wf@KPS`@?@MRi@bAYb@cA~ASTIJEFEBaAv@SVi@b@UT[XY\\OVOXKXSj@Kb@IZS|@UlAQ`AShAO`A[`BWxAMp@Ox@If@EROr@CL?T?JCPOr@AFG\\I\\KZM^Wv@u@|BQj@Sb@GLILIJu@bAyAlBCBEBK?KPOPm@v@iCdDW^_@j@_At@QPYNi@\\y@d@[ROHaAn@oCfBULm@`@k@\\y@h@}Az@_@Zg@\\A@g@^ON{@vAc@p@?A{B~DkAlCcAvEg@c@g@m@w@sAi@oAa@o@_ChI_JaAwIkAkE_@yCc@?@aC[A?u@M_@IKHIDADAD?DAPGbBCLCLGHCBA@C@A@C@E?I?G?g@Ew@Iu@Iq@GICQC?WH{BBu@@M?QVaLBm@FcC@i@@c@FiBF}B@]DiBBq@FqBRsH@m@Bg@P{EJmD@WHyBF{B@_@@K?QBq@?E@C?I?I?S?OAMAK?KCMA?A?A?A?AAA?AAA??AAAAA?AAA?A?AA??A?A?A?AAA?A?A?A?A?A?A?A?AMIMIMESE_@CMAG?OCQCwAMC?iBSeA?o@HkBOo@SgFkDmC{AuAkAc@k@wB{Da@m@c@c@_@UeASeAFe@R[Tc@j@a@t@[~@i@jC}ArJeChKq@pBoDtG_CtD_DrDyBbBwAx@sB`AuBl@eARgCT}Ih@wDpBiKjCmLlIgDlBeFrMy@hBeB|CcC`DwAxAeDhCkB~@mAf@cDr@cBPkBFmGOmLg@oL{@}JqA_r@sKyHmByAg@wDaBkDkBsIgGyOiOyNuNuTeTiEyDyBgBgHaFmGwD{C}AmKoEwNuGyIoDqg@}T}Dy@e@AmBZeAn@}@bAqAhC{@~CYrBo@vOg@fXFpAb@lBBt@Et@c@fBSjBCzAJfBZvA\\x@X^rHjGPd@X`@Tl@Ld@JjA@l@Cj@WnBe@tA_@`BiCdMTR'},
#       'start_location': {'lat': 53.3181143, 'lng': -6.2112678},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.426778,
#          'lng': -6.2395461},
#         'name': 'Dublin Airport'},
#        'arrival_time': {'text': '7:02pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562695320},
#        'departure_stop': {'location': {'lat': 53.3181143, 'lng': -6.2112678},
#         'name': "Merrion, Saint Vincent's Hospital"},
#        'departure_time': {'text': '6:33pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562693580},
#        'headsign': 'Dublin Airport',
#        'line': {'agencies': [{'name': 'Aircoach',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '703',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 7},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 107},
#       'duration': {'text': '2 mins', 'value': 108},
#       'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#       'html_instructions': 'Walk to Corballis, Dublin Airport, Co. Dublin, Ireland',
#       'polyline': {'points': 'k|aeIbtae@@GHHRN`@NL_@Ns@L_AD]'},
#       'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#       'steps': [{'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 2},
#         'end_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'html_instructions': 'Head <b>southeast</b>',
#         'polyline': {'points': 'k|aeIbtae@@G'},
#         'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '6 m', 'value': 6},
#         'duration': {'text': '1 min', 'value': 5},
#         'end_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'html_instructions': 'Turn <b>right</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'i|aeIzsae@HH'},
#         'start_location': {'lat': 53.4267704, 'lng': -6.2394998},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '46 m', 'value': 46},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'html_instructions': 'Walk for 46&nbsp;m',
#         'polyline': {'points': '_|aeIdtae@RN`@NL_@'},
#         'start_location': {'lat': 53.4267209, 'lng': -6.239547099999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 2},
#         'distance': {'text': '19 m', 'value': 19},
#         'duration': {'text': '1 min', 'value': 31},
#         'end_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'html_instructions': 'Take the escalator <b>down</b> to 0',
#         'polyline': {'points': '{yaeIdtae@Ns@'},
#         'start_location': {'lat': 53.4263792, 'lng': -6.239548399999999},
#         'travel_mode': 'WALKING'},
#        {'building_level': {'number': 0},
#         'distance': {'text': '33 m', 'value': 33},
#         'duration': {'text': '1 min', 'value': 28},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Walk for 33&nbsp;m',
#         'polyline': {'points': 'kyaeIprae@L_AD]'},
#         'start_location': {'lat': 53.4263027, 'lng': -6.2392889},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '1 m', 'value': 0},
#         'duration': {'text': '1 min', 'value': 0},
#         'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'html_instructions': 'Head<div style="font-size:0.9em">Destination will be on the left</div>',
#         'polyline': {'points': 'wxaeIroae@'},
#         'start_location': {'lat': 53.4262034, 'lng': -6.238816099999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'wujdInt~d@@LCf@APOE_@MuBc@a@vFgAWwA_@CAOnBQrBMlBMG]i@[[kAjAmB~AGEMFGFEGq@wBeBqFe@eAgA_C_CcGgBeE_AyB[}@gC{FeCsFgEqJiD{HiAgCc@gAOgAUaC_@gCQi@MSb@kAd@mAPo@Po@FFGGQn@Qn@e@lAcAdCwAzCs@pAIH_@v@Wh@c@~@sBbEq@pAkB|CmCxD}ApByAzBmBvDiFlKkA~BqA|BwAtBORgAz@}@z@q@n@i@t@[r@_@nA]xAg@nCc@jCs@zDg@rCUfACb@C\\Qz@Qz@Yz@mAtDe@nAqAjB}ApBQBsE`Gw@jAqAfAyCfBwFnDyA~@wCdBqBzAON{@vAc@n@{B~DkAlCcAvEg@c@g@m@w@sAi@oAa@o@_ChI_JaAwIkAkE_@yCc@?@cC[uAWUNCPItBGZQPUB}CY{@KQC?WLqD@_@d@}RRiHd@aQb@_NZcK@k@Cu@EMC?GCEGEW?EMK[Os@IUA}BUiBSeA?o@HkBOo@SgFkDmC{AuAkAc@k@wB{Da@m@c@c@_@UeASeAFe@R[Tc@j@a@t@[~@i@jC}ArJeChKq@pBoDtG_CtD_DrDyBbBwAx@sB`AuBl@eARgCT}Ih@wDpBiKjCmLlIgDlBeFrMy@hBeB|CcC`DwAxAeDhCkB~@mAf@cDr@cBPkBFmGOmLg@oL{@}JqA_r@sKyHmByAg@wDaBkDkBsIgGyOiOyNuNuTeTiEyDyBgBgHaFmGwD{C}AmKoEwNuGyIoDqg@}T}Dy@e@AmBZeAn@}@bAqAhC{@~CYrBo@vOg@fXFpAb@lBBt@Et@c@fBSjBCzAJfBZvA\\x@X^rHjGPd@X`@b@rAJjA@l@Cj@WnBe@tA_@`BiCdMTR@I\\X`@NL_@Ns@L_AD]'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []}]

# %%
# Shows all different trip options worked out by google
route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]    
route_keys
# Out:
# [dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order']),
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])]

# %%
a["routes"][0]["bounds"]
# Out:
# {'northeast': {'lat': 53.426812, 'lng': -6.2185592},
#  'southwest': {'lat': 53.3079626, 'lng': -6.2611548}}

# %%
# Shows all the steps in a trip
for i, val in enumerate(a["routes"][0]["legs"][0]["steps"]):
    print(i)
    print(val)
# Out:
# 0
# {'distance': {'text': '0.5 km', 'value': 483}, 'duration': {'text': '6 mins', 'value': 350}, 'end_location': {'lat': 53.309375, 'lng': -6.2187873}, 'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)', 'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'}, 'start_location': {'lat': 53.3079626, 'lng': -6.2242422}, 'steps': [{'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 53.3079626, 'lng': -6.2242422}, 'html_instructions': 'Head', 'polyline': {'points': 'wujdInt~d@'}, 'start_location': {'lat': 53.3079626, 'lng': -6.2242422}, 'travel_mode': 'WALKING'}, {'building_level': {'number': 0}, 'distance': {'text': '68 m', 'value': 68}, 'duration': {'text': '1 min', 'value': 54}, 'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001}, 'html_instructions': 'Walk for 68&nbsp;m', 'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'}, 'start_location': {'lat': 53.3079626, 'lng': -6.2242422}, 'travel_mode': 'WALKING'}, {'distance': {'text': '45 m', 'value': 45}, 'duration': {'text': '1 min', 'value': 32}, 'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999}, 'html_instructions': 'Head <b>northeast</b>', 'polyline': {'points': 'uwjdIpo~d@YsAQY'}, 'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001}, 'travel_mode': 'WALKING'}, {'distance': {'text': '24 m', 'value': 24}, 'duration': {'text': '1 min', 'value': 15}, 'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999}, 'html_instructions': 'Slight <b>left</b>', 'maneuver': 'turn-slight-left', 'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'}, 'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '37 m', 'value': 37}, 'duration': {'text': '1 min', 'value': 24}, 'end_location': {'lat': 53.3089313, 'lng': -6.2225063}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'}, 'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '50 m', 'value': 50}, 'duration': {'text': '1 min', 'value': 31}, 'end_location': {'lat': 53.3091217, 'lng': -6.2218379}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'}, 'start_location': {'lat': 53.3089313, 'lng': -6.2225063}, 'travel_mode': 'WALKING'}, {'distance': {'text': '93 m', 'value': 93}, 'duration': {'text': '1 min', 'value': 75}, 'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'}, 'start_location': {'lat': 53.3091217, 'lng': -6.2218379}, 'travel_mode': 'WALKING'}, {'distance': {'text': '87 m', 'value': 87}, 'duration': {'text': '1 min', 'value': 63}, 'end_location': {'lat': 53.3092212, 'lng': -6.2198063}, 'html_instructions': 'Turn <b>left</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'}, 'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '15 m', 'value': 15}, 'duration': {'text': '1 min', 'value': 13}, 'end_location': {'lat': 53.3091366, 'lng': -6.2196227}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 's}jdIxx}d@HYDK'}, 'start_location': {'lat': 53.3092212, 'lng': -6.2198063}, 'travel_mode': 'WALKING'}, {'distance': {'text': '64 m', 'value': 64}, 'duration': {'text': '1 min', 'value': 43}, 'end_location': {'lat': 53.309375, 'lng': -6.2187873}, 'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'}, 'start_location': {'lat': 53.3091366, 'lng': -6.2196227}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}
# 1
# {'distance': {'text': '17.5 km', 'value': 17509}, 'duration': {'text': '41 mins', 'value': 2460}, 'end_location': {'lat': 53.426778, 'lng': -6.2395461}, 'html_instructions': 'Bus towards Dublin Airport', 'polyline': {'points': 'y~jdI|r}d@k@}@{@vBc@z@GL[f@a@h@SVUTUR]XKHi@`@IFk@^yA`AcAr@{@j@s@h@[Z[V[`@A@c@p@q@jAUf@Sh@Of@Oj@WdAEPMp@[jA?B]hAMh@KZKZEAELa@fAIUHSX}@n@{BdAwEp@yBp@_BLRk@rAY|@sCxKELmA~CuA|BmJpNaIhMUNkBtCy@~@@B{AvBEFk@x@Yj@q@fAKLGJw@nA[h@g@z@OXIPIROj@Q~BI^O^IRMXOTCFS^]p@Ub@{ArBINGFMRQTQT[^c@l@u@hAYb@aBbCGHGHm@z@W`@QTOTKRe@v@A@uApBIJoA`Bc@j@m@x@s@fAi@t@c@v@CHITELITK\\GNW`A?@Mf@Wx@EPMd@Od@YdASr@Ur@KZINCJ[z@AJ?BABIVK\\Of@Kb@AJG`@_@zDM~@Mn@On@K`@]~@U`@Ud@U\\Y^MNMLa@Xu@f@SHEBC@QFUJGD_@PaAn@KDSASNIFEBIFaAjAc@d@g@j@IHONc@b@sBdCw@v@QPe@d@[\\i@f@g@h@m@p@OPWXCDEDkAnA_@h@KVEHEFIX[Si@_@KGy@i@YScAs@SQwB{A[Y[YGACAE?G?MDGBED?@EFCFGVEXADAFCEYlBWSg@a@cEaCiCsAgGgC`@uDVgBDmAQoBg@yB@u@PcAFy@OWuEgCwCyAU@YVGVgBbNE\\mB`Qe@rDU~BKfDz@lDZt@^|@b@j@pAbAjA{@PCt@Af@LV@ZWHWfBkM@E@@Ly@D[XwBDa@h@cEf@uDP_B@CBUBg@@S@e@AKAECKM_@Om@GWKc@CM?G?AAG?K@OBYD]LmABYSKYOgCsAoBcAMIEA[OGCQKS?I@G@IDGFILG`@OjAm@rEKr@Ej@MlAE^Q~AQxAi@tFE^M|@@RALANEPETAHQdAGVUhA?BE\\ANCXCj@AZ?t@AJ?F?H@H?JBL@JFZNp@Lh@Lh@?L?H@N@T?RCz@}@?W@M?w@Ay@?y@C]CS@K@C@IBc@R]NMFKFU@}Br@IBGBG@YLI@mA`@SFkC|@{Af@aEtAmA`@@EcfAaPSEmmKqrBD_A'}, 'start_location': {'lat': 53.3094098, 'lng': -6.2188692}, 'transit_details': {'arrival_stop': {'location': {'lat': 53.426778, 'lng': -6.2395461}, 'name': 'Dublin Airport'}, 'arrival_time': {'text': '6:53pm', 'time_zone': 'Europe/Dublin', 'value': 1562694780}, 'departure_stop': {'location': {'lat': 53.3094098, 'lng': -6.2188692}, 'name': 'Dublin (UCD Stillorgan Rd Flyover)'}, 'departure_time': {'text': '6:12pm', 'time_zone': 'Europe/Dublin', 'value': 1562692320}, 'headsign': 'Dublin Airport', 'line': {'agencies': [{'name': 'Aircoach', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '700', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 13}, 'travel_mode': 'TRANSIT'}
# 2
# {'distance': {'text': '0.1 km', 'value': 107}, 'duration': {'text': '2 mins', 'value': 108}, 'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999}, 'html_instructions': 'Walk to Corballis, Dublin Airport, Co. Dublin, Ireland', 'polyline': {'points': 'k|aeIbtae@@GHHRN`@NL_@Ns@L_AD]'}, 'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999}, 'steps': [{'distance': {'text': '3 m', 'value': 3}, 'duration': {'text': '1 min', 'value': 2}, 'end_location': {'lat': 53.4267704, 'lng': -6.2394998}, 'html_instructions': 'Head <b>southeast</b>', 'polyline': {'points': 'k|aeIbtae@@G'}, 'start_location': {'lat': 53.4267826, 'lng': -6.239542399999999}, 'travel_mode': 'WALKING'}, {'distance': {'text': '6 m', 'value': 6}, 'duration': {'text': '1 min', 'value': 5}, 'end_location': {'lat': 53.4267209, 'lng': -6.239547099999999}, 'html_instructions': 'Turn <b>right</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'i|aeIzsae@HH'}, 'start_location': {'lat': 53.4267704, 'lng': -6.2394998}, 'travel_mode': 'WALKING'}, {'building_level': {'number': 2}, 'distance': {'text': '46 m', 'value': 46}, 'duration': {'text': '1 min', 'value': 42}, 'end_location': {'lat': 53.4263792, 'lng': -6.239548399999999}, 'html_instructions': 'Walk for 46&nbsp;m', 'polyline': {'points': '_|aeIdtae@RN`@NL_@'}, 'start_location': {'lat': 53.4267209, 'lng': -6.239547099999999}, 'travel_mode': 'WALKING'}, {'building_level': {'number': 2}, 'distance': {'text': '19 m', 'value': 19}, 'duration': {'text': '1 min', 'value': 31}, 'end_location': {'lat': 53.4263027, 'lng': -6.2392889}, 'html_instructions': 'Take the escalator <b>down</b> to 0', 'polyline': {'points': '{yaeIdtae@Ns@'}, 'start_location': {'lat': 53.4263792, 'lng': -6.239548399999999}, 'travel_mode': 'WALKING'}, {'building_level': {'number': 0}, 'distance': {'text': '33 m', 'value': 33}, 'duration': {'text': '1 min', 'value': 28}, 'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999}, 'html_instructions': 'Walk for 33&nbsp;m', 'polyline': {'points': 'kyaeIprae@L_AD]'}, 'start_location': {'lat': 53.4263027, 'lng': -6.2392889}, 'travel_mode': 'WALKING'}, {'distance': {'text': '1 m', 'value': 0}, 'duration': {'text': '1 min', 'value': 0}, 'end_location': {'lat': 53.4262034, 'lng': -6.238816099999999}, 'html_instructions': 'Head<div style="font-size:0.9em">Destination will be on the left</div>', 'polyline': {'points': 'wxaeIroae@'}, 'start_location': {'lat': 53.4262034, 'lng': -6.238816099999999}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}

# %%
# Shows only steps with bus 
print(a["routes"][0]["legs"][0]["steps"][1]["transit_details"])
# Out:
# {'arrival_stop': {'location': {'lat': 53.426778, 'lng': -6.2395461}, 'name': 'Dublin Airport'}, 'arrival_time': {'text': '6:53pm', 'time_zone': 'Europe/Dublin', 'value': 1562694780}, 'departure_stop': {'location': {'lat': 53.3094098, 'lng': -6.2188692}, 'name': 'Dublin (UCD Stillorgan Rd Flyover)'}, 'departure_time': {'text': '6:12pm', 'time_zone': 'Europe/Dublin', 'value': 1562692320}, 'headsign': 'Dublin Airport', 'line': {'agencies': [{'name': 'Aircoach', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '700', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 13}

# %%
print("vehicle: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["vehicle"]["type"])
print()
print("dep stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"])
print()
print("arr stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"])
print()
print("headsign: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["headsign"])
print()
print("route name: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["short_name"])
print()
print("num_stops: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["num_stops"])
print()
print("dep time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
print()
print("arri time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
print()
arr = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
dep = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
tot = datetime.timedelta(seconds=(arr - dep))
print("total time: ", tot)
# Out:
# vehicle:  BUS
#
# dep stop:  {'location': {'lat': 53.3094098, 'lng': -6.2188692}, 'name': 'Dublin (UCD Stillorgan Rd Flyover)'}
#
# arr stop:  Dublin Airport
#
# headsign:  Dublin Airport
#
# route name:  700
#
# num_stops:  13
#
# dep time:  1562692320
#
# arri time:  1562694780
#
# total time:  0:41:00

# %%
for i in range(len(route_keys)):
    for j in range(len(a["routes"][i]["legs"][0]["steps"])):
    
        if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
            print("Vehicle: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"])
            
            print("dep stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"])
            
            print("arr stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"])
            
            print("headsign: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"])
                  
            print("route name: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"])
                  
            print("num_stops: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["num_stops"])
            
            arr = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_time"]["value"])
            dep = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_time"]["value"])
            tot = datetime.timedelta(seconds=(arr - dep))
            print("totalbus trip time: ", tot)
                  
            print("step number", j)
            print("option number:", i)
            print()
            
    print("-----------------------------------------------------")
    print()
# Out:
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Dublin Airport
# headsign:  Dublin Airport
# route name:  700
# num_stops:  13
# totalbus trip time:  0:41:00
# step number 1
# option number: 0
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Dublin Airport
# headsign:  Dublin Airport
# route name:  700
# num_stops:  13
# totalbus trip time:  0:41:00
# step number 1
# option number: 1
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Dublin (UCD Stillorgan Rd Flyover)
# arr stop:  Dublin City South, Upper Baggot Street
# headsign:  Ongar
# route name:  39a
# num_stops:  13
# totalbus trip time:  0:10:38
# step number 1
# option number: 2
#
# Vehicle:  BUS
# dep stop:  Dublin City South, Northumberland Road
# arr stop:  Dublin Airport
# headsign:  Dublin Airport
# route name:  703
# num_stops:  3
# totalbus trip time:  0:22:00
# step number 3
# option number: 2
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Merrion, Saint Vincent's Hospital
# arr stop:  Dublin Airport
# headsign:  Dublin Airport
# route name:  703
# num_stops:  7
# totalbus trip time:  0:29:00
# step number 1
# option number: 3
#
# -----------------------------------------------------

# %%
# This are stop names not addresses:

# stopA = "Outside Heuston Train Station"
# stopB = "Temple Bar, Parliament Street"

# stopA = "Marino, East South B. Sub Station"
# stopB = "Clifton Court Hotel Eden Quay"

# stopA = "Dublin City South, Camden Street"
# stopB = "Fairview, Marino College Fairview"

# stopA = "Dublin (UCD Stillorgan Rd Flyover)"
# stopB = "Dublin City South, Westmoreland Street"

# stopA = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"]["name"]
# stopB = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"]
# print(stopA)
# print(stopB)


query1 = """SELECT stop_lat,stop_lon,stop_id,stop_name 
        FROM research.stops 
        WHERE stop_name LIKE %s or stop_name LIKE %s"""

query1b = """SELECT stop_lat,stop_lon,stop_id,stop_name 
        FROM research.stops 
        WHERE stop_name LIKE %s"""

query2 = """SELECT distinct research.stop_times.bus_number  
        FROM research.stop_times 
        WHERE research.stop_times.bus_number=%s and research.stop_times.bus_stop_number=%s and research.stop_times.headsign=%s"""


query3 = """SELECT research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.trips.direction_id, research.stop_times.headsign 
        FROM research.stop_times, research.trips 
        WHERE stop_times.trip_id = trips.trip_id and stop_times.headsign = %s and stop_times.bus_number = %s and (bus_stop_number = %s or bus_stop_number = %s)"""


query4 = """SELECT research.stops.stop_lat, research.stops.stop_lon, research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.stop_times.headsign, research.stop_times.bus_number 
        FROM research.stop_times, research.stops
        WHERE bus_number = %s and headsign = %s and (stop_sequence between %s AND %s)
        LIMIT %s
        """

# %%
def db_query(query, stopA, stopB):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    
    cur = con.cursor()
    cur.execute(query, ('%'+stopA+'%', '%'+stopB+'%'), )
    data = cur.fetchall()
    cur.close()   
      
    
    return data

# %%
# b = db_query(query1b, stopA, stopB)
# b

# %%
def db_query2(query, bus_no, stop_no, head_sign):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)

    cur = con.cursor()
    cur.execute(query, (bus_no, stop_no, head_sign),)
    data = list(cur.fetchall())

    if len(data) > 0:
        data.pop()
        data.append(bus_no)
        data.append(head_sign)
    cur.close()
    
    return data

# %%
def start_end(b, bus_no, headsign):
# def start_end(b):
    c = []
    
    for i in b:
        
#         z = db_query2(query2, "145", i[2], "Heuston Station")
        z = db_query2(query2, bus_no, i[2], headsign)

        if(len(z) != 0):
            z.append(i[0])
            z.append(i[1])
            z.append(i[2])
            z.append(i[3])
            c.append(z)
    return c

# %%
def db_query3(query, head_sign, bus_no, stop_noA, stop_noB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    cur = con.cursor()
    cur.execute(query, (head_sign, bus_no, stop_noA, stop_noB),)
    cur.close()
    return cur.fetchall()

# %%
# e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])
# e

# %%
def db_query4(query, bus_no, head_sign, seqA, seqB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
    limit = seqB - seqA + 1
    cur = con.cursor()
    cur.execute(query, (bus_no, head_sign, seqA, seqB, limit),)
    cur.close()
    return cur.fetchall()

# %%
# f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
# f

# %%
# a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS"
a["routes"][0]["legs"][0]["steps"][0]
# Out:
# {'distance': {'text': '0.5 km', 'value': 483},
#  'duration': {'text': '6 mins', 'value': 350},
#  'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#  'html_instructions': 'Walk to Dublin (UCD Stillorgan Rd Flyover)',
#  'polyline': {'points': 'wujdInt~d@AGGGi@o@I}AYsAQYMEIAGAGAABG_@CGAECEKKGEG?AIEUGSK_@AIGU?QPm@j@kBXw@@E@G@EEKGMIMYe@CGOUKOMUQ]HYDKUmASw@CMBIEG'},
#  'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#  'steps': [{'distance': {'text': '1 m', 'value': 0},
#    'duration': {'text': '1 min', 'value': 0},
#    'end_location': {'lat': 53.3079626, 'lng': -6.2242422},
#    'html_instructions': 'Head',
#    'polyline': {'points': 'wujdInt~d@'},
#    'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#    'travel_mode': 'WALKING'},
#   {'building_level': {'number': 0},
#    'distance': {'text': '68 m', 'value': 68},
#    'duration': {'text': '1 min', 'value': 54},
#    'end_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#    'html_instructions': 'Walk for 68&nbsp;m',
#    'polyline': {'points': 'wujdInt~d@AGGGi@o@I}A'},
#    'start_location': {'lat': 53.3079626, 'lng': -6.2242422},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '45 m', 'value': 45},
#    'duration': {'text': '1 min', 'value': 32},
#    'end_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#    'html_instructions': 'Head <b>northeast</b>',
#    'polyline': {'points': 'uwjdIpo~d@YsAQY'},
#    'start_location': {'lat': 53.3082682, 'lng': -6.223450400000001},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '24 m', 'value': 24},
#    'duration': {'text': '1 min', 'value': 15},
#    'end_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#    'html_instructions': 'Slight <b>left</b>',
#    'maneuver': 'turn-slight-left',
#    'polyline': {'points': 'ayjdIbl~d@MEIAGAGAAB'},
#    'start_location': {'lat': 53.3084922, 'lng': -6.222899399999999},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '37 m', 'value': 37},
#    'duration': {'text': '1 min', 'value': 24},
#    'end_location': {'lat': 53.3089313, 'lng': -6.2225063},
#    'html_instructions': 'Turn <b>right</b>',
#    'maneuver': 'turn-right',
#    'polyline': {'points': 'kzjdIzk~d@G_@CGAECEKKGEG?'},
#    'start_location': {'lat': 53.3087034, 'lng': -6.222856699999999},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '50 m', 'value': 50},
#    'duration': {'text': '1 min', 'value': 31},
#    'end_location': {'lat': 53.3091217, 'lng': -6.2218379},
#    'html_instructions': 'Turn <b>right</b>',
#    'maneuver': 'turn-right',
#    'polyline': {'points': 'y{jdIti~d@AIEUGSK_@AIGU?Q'},
#    'start_location': {'lat': 53.3089313, 'lng': -6.2225063},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '93 m', 'value': 93},
#    'duration': {'text': '1 min', 'value': 75},
#    'end_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#    'html_instructions': 'Turn <b>right</b>',
#    'maneuver': 'turn-right',
#    'polyline': {'points': '_}jdIne~d@Pm@j@kBXw@@E@G@E'},
#    'start_location': {'lat': 53.3091217, 'lng': -6.2218379},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '87 m', 'value': 87},
#    'duration': {'text': '1 min', 'value': 63},
#    'end_location': {'lat': 53.3092212, 'lng': -6.2198063},
#    'html_instructions': 'Turn <b>left</b>',
#    'maneuver': 'turn-left',
#    'polyline': {'points': 'azjdIh~}d@EKGMIMYe@CGOUKOMUQ]'},
#    'start_location': {'lat': 53.3086475, 'lng': -6.220688099999999},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '15 m', 'value': 15},
#    'duration': {'text': '1 min', 'value': 13},
#    'end_location': {'lat': 53.3091366, 'lng': -6.2196227},
#    'html_instructions': 'Turn <b>right</b>',
#    'maneuver': 'turn-right',
#    'polyline': {'points': 's}jdIxx}d@HYDK'},
#    'start_location': {'lat': 53.3092212, 'lng': -6.2198063},
#    'travel_mode': 'WALKING'},
#   {'distance': {'text': '64 m', 'value': 64},
#    'duration': {'text': '1 min', 'value': 43},
#    'end_location': {'lat': 53.309375, 'lng': -6.2187873},
#    'html_instructions': 'Turn <b>left</b><div style="font-size:0.9em">Destination will be on the left</div>',
#    'maneuver': 'turn-left',
#    'polyline': {'points': 'c}jdIrw}d@UmASw@CMBIEG'},
#    'start_location': {'lat': 53.3091366, 'lng': -6.2196227},
#    'travel_mode': 'WALKING'}],
#  'travel_mode': 'WALKING'}

# %%
final_list = []

def fin(a):
    
    route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]
    
    for i in range(len(route_keys)):
        should_count = 0
        is_count = 0
        interm_legs = []
        for j in range(len(a["routes"][i]["legs"][0]["steps"])):
            
            if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
                should_count += 1
                dep_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"]
                arr_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"]
                bus_no = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"]
                head_sign = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"]
                
                b = db_query(query1, dep_stop, arr_stop)
                print("Query 1: ")
                print(b)
                if len(b) > 1:
                    d = start_end(b, bus_no, head_sign)
                    print("Query 2: ")
                    print(d)
                    e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4]) 
                    print("Query 3: ")
                    print(e)
                    if (len(e) > 0):
                        f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
                        print("Final: ")
                        print(f)
                        is_count += 1
                        interm_legs.append(f)                            
                        
                    else:
                        pass
                else:
                    pass
                
            else:
                pass
            
            print("step1: ", j)
            
        if should_count == is_count:
            print("Number of positive legs obtained: ", len(interm_legs))
            final_list.append(interm_legs)
                
        
        print("option: ", i)
        print("*****************************************************************")
        
fin(a)
# Out:
# step1:  0
# Query 1:
# (('53.4268556196', '-6.23926975991', '8240DB007400_merged_7772', 'Dublin Airport'), ('53.4259684913', '-6.22911885212', '8240DB003885', 'Dublin Airport, The Radisson Hotel'), ('53.4267574671', '-6.24053788096', '8240DB007401_merged_7776', 'Dublin Airport'), ('53.309418194', '-6.21877482979', '8250DB000768', 'Dublin (UCD Stillorgan Rd Flyover)'), ('53.4182519907', '-6.30686273203', '8240DB001555', "St. Margaret's, Dublin Airport Logistics Park"), ('53.4131980312', '-6.26534792574', '8240DB000327', 'Dublin Airport, Silloge Golf Club'), ('53.4129298607', '-6.26544910097', '8240DB000323', 'Dublin Airport, Silloge Golf Club'), ('53.4321755005', '-6.23007985141', '8240DB003672', 'Dublin Airport, Swords Road'), ('53.4245772535', '-6.2298538278', '8240DB003670', 'Dublin Airport, The Radisson Hotel'), ('53.4293994598', '-6.23016510811', '8240DB003671', 'Dublin Airport, Dublin Airport Roundabout'), ('53.4280546994', '-6.24195908471', '8240DB007347_merged_7777', 'Dublin Airport'), ('53.421679994', '-6.23146381611', '8240DB001631', 'Dublin Airport, A.L.S.A.A. Sports Club'), ('53.4205001547', '-6.23312273045', '8240DB001632', 'Dublin Airport, Toberbunny Lodge'), ('53.4177822289', '-6.2377489951', '8240DB001633', 'Dublin Airport, Dardistown Cemetery'), ('53.4168918499', '-6.23892922854', '8240DB001634', 'Dublin Airport, Collinstown Business Park'), ('53.4117049122', '-6.23887277719', '8240DB001635', 'Dublin Airport, Sports Ground'), ('53.4281137332', '-6.24413873208', '8240DB003665', 'Dublin Airport'), ('53.4245981576', '-6.2349089651', '8240DB003663', 'Dublin Airport, Airport Terminal 2'), ('53.4284655392', '-6.23507978936', '8240DB003669', 'Dublin Airport, Maldron Hotel'), ('53.4166259208', '-6.2391809352', '8240DB001629', 'Dublin Airport, Dardistown Cemetery'), ('53.4137122404', '-6.23907566145', '8240DB001628', 'Dublin Airport, Collinstown Business'), ('53.4191328991', '-6.23548141801', '8240DB005053', 'Dublin Airport, Main Airport Runway'), ('53.4216316663', '-6.23184198689', '8240DB001630', 'Dublin Airport, A.L.S.A.A. Sports Club'), ('53.4278625225', '-6.24172623591', '8240DB007401_merged_7773', 'Dublin Airport'), ('53.427815838', '-6.2416077729', '8240DB007348', 'Dublin Airport'), ('53.4252783851', '-6.23471525445', '8240DB007349', 'Dublin Airport, Great Southern Hotel'), ('53.4267857549', '-6.23940808319', '8240DB007400_merged_7775', 'Dublin Airport'), ('53.4278151736', '-6.24156265407', '8240DB007347_merged_7774', 'Dublin Airport'))
# Query 2:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-174-7f14e0f41573> in <module>()
#      53         print("*****************************************************************")
#      54
# ---> 55 fin(a)
#
# <ipython-input-174-7f14e0f41573> in fin(a)
#      25                     print("Query 2: ")
#      26                     print(d)
# ---> 27                     e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])
#      28                     print("Query 3: ")
#      29                     print(e)
#
# IndexError: list index out of range

# %%
print(len(final_list))
# Out:
# 0

# %%
final_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-176-853b37056cf3> in <module>()
# ----> 1 final_list[0]
#
# IndexError: list index out of range
