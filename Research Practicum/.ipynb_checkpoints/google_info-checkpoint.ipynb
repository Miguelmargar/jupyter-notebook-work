# %%
import requests, json, datetime, pymysql, sys, csv, difflib

# %%
def get_direct_goo():
    
#     "Fairview, County Dublin, Ireland"
#     "Killiney, County Dublin, Ireland"

#     "Heuston Station, Saint John's Road West, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

#     "University College Dublin, Belfield, Dublin, Ireland"
#     "Temple Bar, Dublin, Ireland"

    postA = "Fairview, County Dublin, Ireland"
    postB = "Killiney, County Dublin, Ireland"

    api_key = 'AIzaSyBi-bH5_sngxNibrgygRZDhmAv2fK5hzus'
    url ='https://maps.googleapis.com/maps/api/directions/json?alternatives=true&transit_mode=bus&'

    req = requests.get(url + 'origin=' + postA +'&destination=' + postB
                     +'&sensor='+"false"+'&mode='+"transit"+'&key=' + api_key)

    return req.json()

a = get_direct_goo()

# %%
a.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
# Everything together
a["routes"]
# Out:
# [{'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1149969},
#    'southwest': {'lat': 53.2650017, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '8:42pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562787756},
#     'departure_time': {'text': '7:15pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562782520},
#     'distance': {'text': '21.1 km', 'value': 21079},
#     'duration': {'text': '1 hour 27 mins', 'value': 5236},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.9 km', 'value': 2944},
#       'duration': {'text': '10 mins', 'value': 622},
#       'end_location': {'lat': 53.34775459999999, 'lng': -6.2584683},
#       'html_instructions': 'Bus towards Eden Quay',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBB?ArA|ApBrBzLtGr@x@t@X~@?z@Oj@FBfH?jI?UHrDPhBlArN'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.34775459999999,
#          'lng': -6.2584683},
#         'name': 'Dublin, Eden Quay'},
#        'arrival_time': {'text': '7:26pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562783182},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '7:16pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562782560},
#        'headsign': 'Eden Quay',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27b',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 8},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 101},
#       'duration': {'text': '1 min', 'value': 83},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'onrdIniee@Hr@@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.34776189999999, 'lng': -6.258322499999999},
#       'steps': [{'distance': {'text': '56 m', 'value': 56},
#         'duration': {'text': '1 min', 'value': 42},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>',
#         'polyline': {'points': 'onrdIniee@Hr@@JHh@Ht@'},
#         'start_location': {'lat': 53.34776189999999,
#          'lng': -6.258322499999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCj@U'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '16.2 km', 'value': 16240},
#       'duration': {'text': '42 mins', 'value': 2511},
#       'end_location': {'lat': 53.2673832, 'lng': -6.134360999999999},
#       'html_instructions': 'Bus towards Brides Glen',
#       'polyline': {'points': 'gkrdIjlee@DRrA{@n@u@zBqDNOJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@h@cEf@uDP_B@CBUBg@@S@e@JQDIBGLa@DMTeAFOb@kBTy@DQ`@_BNm@x@gD~AqGH]@?VeARu@V_AViA^uAPs@FWVgAFWh@_Cb@cBAC@BPm@VaAFWDOVcALo@BILc@DUH]`@mBP}@h@gCFSHSPg@JORa@x@_BVe@NW^o@l@_Az@wANOf@_@@Af@]^[v@c@d@Wx@i@j@]l@a@TMnCgB`Ao@NIZSx@e@h@]XOPQ~@u@^k@V_@HMlDoENQJQJS`@k@x@iAf@y@n@kAXs@t@}BFUBETq@BIFQLg@Jk@BGFa@HU@CFKBMJi@BIDS

#       'transit_details': {'arrival_stop': {'location': {'lat': 53.2673832,
#          'lng': -6.134360999999999},
#         'name': 'Glenageary Heights, Sallyglen'},
#        'arrival_time': {'text': '8:18pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562786306},
#        'departure_stop': {'location': {'lat': 53.3472395,
#          'lng': -6.258775900000001},
#         'name': "O'Connell Bridge Bus Stop"},
#        'departure_time': {'text': '7:36pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562783795},
#        'headsign': 'Brides Glen',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '7',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 43},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '1.7 km', 'value': 1736},
#       'duration': {'text': '24 mins', 'value': 1450},
#       'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#       'html_instructions': 'Walk to Scalpwilliam, Killiney, Co. Dublin, Ireland',
#       'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yCJKZ_@P[T]NWHUDKFSDMLcAPcAHg@Fg@`A{@NObAo@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_AV?H_@HYHMl@iAXk@Rk@`@cAb@oADYI{@PBL@TCj@Wh@c@j@Y'},
#       'start_location': {'lat': 53.267384, 'lng': -6.1345433},
#       'steps': [{'distance': {'text': '0.1 km', 'value': 113},
#         'duration': {'text': '1 min', 'value': 83},
#         'end_location': {'lat': 53.2664883, 'lng': -6.1340892},
#         'html_instructions': 'Head <b>south</b> on <b>Thomastown Rd</b> toward <b>Ballinclea Rd</b>',
#         'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@'},
#         'start_location': {'lat': 53.267384, 'lng': -6.1345433},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.7 km', 'value': 715},
#         'duration': {'text': '9 mins', 'value': 562},
#         'end_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'html_instructions': 'Turn <b>left</b> onto <b>Ballinclea Rd</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'qrbdI`amd@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yC'},
#         'start_location': {'lat': 53.2664883, 'lng': -6.1340892},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '90 m', 'value': 90},
#         'duration': {'text': '1 min', 'value': 80},
#         'end_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'html_instructions': 'Turn <b>right</b> toward <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'ydcdI|gkd@JKZ_@P[T]NWHUDKFS'},
#         'start_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 176},
#         'duration': {'text': '3 mins', 'value': 161},
#         'end_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'html_instructions': 'Continue onto <b>Ballinclea Heights</b>',
#         'polyline': {'points': 'aacdIhbkd@DMLcAPcAHg@Fg@`A{@NObAo@'},
#         'start_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.3 km', 'value': 324},
#         'duration': {'text': '4 mins', 'value': 269},
#         'end_location': {'lat': 53.2669794, 'lng': -6.1177607},
#         'html_instructions': 'Turn <b>left</b> to stay on <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'szbdIfwjd@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_A'},
#         'start_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '13 m', 'value': 13},
#         'duration': {'text': '1 min', 'value': 15},
#         'end_location': {'lat': 53.26685939999999, 'lng': -6.1177624},
#         'html_instructions': 'Turn <b>right</b> onto <b>Rock Lodge</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'subdI~zid@V?'},
#         'start_location': {'lat': 53.2669794, 'lng': -6.1177607},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 176},
#         'duration': {'text': '3 mins', 'value': 176},
#         'end_location': {'lat': 53.26587, 'lng': -6.11572},
#         'html_instructions': 'Turn <b>left</b> to stay on <b>Rock Lodge</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': '{tbdI~zid@H_@HYHMl@iAXk@Rk@`@cAb@oADY'},
#         'start_location': {'lat': 53.26685939999999, 'lng': -6.1177624},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '21 m', 'value': 21},
#         'duration': {'text': '1 min', 'value': 20},
#         'end_location': {'lat': 53.2659218, 'lng': -6.115418699999999},
#         'html_instructions': 'Slight <b>left</b> onto <b>Claremont Rd</b>',
#         'maneuver': 'turn-slight-left',
#         'polyline': {'points': 'unbdIfnid@I{@'},
#         'start_location': {'lat': 53.26587, 'lng': -6.11572},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.1 km', 'value': 108},
#         'duration': {'text': '1 min', 'value': 84},
#         'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#         'html_instructions': 'Turn <b>right</b> onto <b>Killiney Hill Rd</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': '_obdIjlid@PBL@TCj@Wh@c@j@Y'},
#         'start_location': {'lat': 53.2659218, 'lng': -6.115418699999999},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'}],
#     'traffic_speed_entry': [],
#     'via_waypoint': []}],
#   'overview_polyline': {'points': 'syudIjy_e@|@_CCCFOGNh@`ALBG`@F~ABh@LjCf@`EbAnFxB~K`@lBDh@NPj@p@|BrCDIrBdC`DfE`KxKbC~DzAlCtCfFzBtDdBlCdC`DvDdEzClDfAtArAzApBrBzLtGr@x@t@X~@?z@Oj@FBfH?jI?UHrDPhBlArNA]J~@R~AlAi@EYDRrA{@n@u@jCaEJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@pAyJZaDBy@P[l@}BfAgEbGaVrDkO`@gBRi@|@mDlCeMn@_BtB_ElAoBjAgBpB{AfGsDlK{G~@u@^k@`@m@|DaFVe@zAuBvAeCzAmEn@uB`@kBXgAb@_CxCoPp@cCZs@h@u@nBkBjBeBfCgEl@iAxIoQxBoDZc@`CaDvAsB|CoF`DuGl@oAd@qArAaDhBoE`AwD~@oEd@wCfAqFt@cDdAwDlBsEpCgFz@iAdAaAzB}A`EmCnCeB|@q@`CuB|@gAbBeDlGuMdAyCfAcCtAkCj@iAb@{Ah@cDLY`@yDZoB|@wDl@mBbGqJbCiF|@{Bn@wBhA}CnBcErBkDFk@|@iDLe@FqAHoAOm@Q}@QiACg@H{Az@kFNe@p@qAt@yARY~@s@zAwA|AiC^_Af@yA^oAl@aB`@cAt@wAh@}@`@_@fDkIl@sA^e@NU`ByAz@k@NE@KFi@bAsGd@oDn@iFJcB|B_Zl@}HPuBD@EABYRiCDm@bAuLd@gG?}BM_B@}CNmD@wEKgC]}BqAmGiAsEa@uBMaAEsAHkGFkEDwCyAGiACG?MEU[KU]c@GgDFkG~BkPh@oDJq@jAkExAiF~DzDjDnD`A`Af@_Bx@gC`DoJhHiTtUzMnEhCzDrB?A?C@C@ABAD@@PNLnF~CbInEhB|@HEp@RHWJMNEN@LJJRBJTDjCO|Do@fJcBxAYhCWvBKFAvGE|JPpUn@j@@vA_@V[J_@L{AUgC_@mAm@}@}@m@wO_JaBwAoA{AQXqAbEb@z@t@v@T`AIbPrTd@@g@?b@~A@LEb@s@HYHIJ@@[C_ACm@e@cBWo@@_BYuCwAcJgCsLc@cAmAuA_Ay@M_@Qi@W_Aa@yCJKl@{@t@wAl@iDPoApAkAbAo@E[CaB@{CLyBVqBf@oB|@uDL[L_AV?H_@Rg@fAuBt@oBh@iBI{@PBb@Aj@Wh@c@j@Y'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.36490269999999,
#     'lng': -6.106811299999999},
#    'southwest': {'lat': 53.2648407, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '8:58pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562788680},
#     'departure_time': {'text': '7:32pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562783532},
#     'distance': {'text': '21.4 km', 'value': 21363},
#     'duration': {'text': '1 hour 26 mins', 'value': 5148},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2648407, 'lng': -6.1150125},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.9 km', 'value': 2948},
#       'duration': {'text': '11 mins', 'value': 643},
#       'end_location': {'lat': 53.3478299, 'lng': -6.258418400000001},
#       'html_instructions': 'Bus towards Jobstown',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBBBA@@@tGjDr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHhBZvDPAFzE'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3478299,
#          'lng': -6.258418400000001},
#         'name': 'Clifton Court Hotel Eden Quay'},
#        'arrival_time': {'text': '7:43pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562784215},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '7:32pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562783572},
#        'headsign': 'Jobstown',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '27',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 9},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.1 km', 'value': 95},
#       'duration': {'text': '1 min', 'value': 79},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#       'steps': [{'distance': {'text': '50 m', 'value': 50},
#         'duration': {'text': '1 min', 'value': 38},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Harbour Ct</b>',
#         'polyline': {'points': 'knrdI`jee@D`@@JHh@Ht@'},
#         'start_location': {'lat': 53.3477444, 'lng': -6.258406799999999},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCj@U'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text':
warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1149969},
#    'southwest': {'lat': 53.2650017, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '8:42pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562787756},
#     'departure_time': {'text': '7:13pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562782438},
#     'distance': {'text': '21.3 km', 'value': 21332},
#     'duration': {'text': '1 hour 29 mins', 'value': 5318},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '3.2 km', 'value': 3159},
#       'duration': {'text': '15 mins', 'value': 894},
#       'end_location': {'lat': 53.3462506, 'lng': -6.2576572},
#       'html_instructions': 'Bus towards Dundrum Luas',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBt@^vAp@CHnCvAr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHlBDn@JjAHv@~BKPpBTxAN|@ZNdAiAbAcBBEKW'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3462506,
#          'lng': -6.2576572},
#         'name': 'Dublin City South, Ashfield House'},
#        'arrival_time': {'text': '7:29pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562783372},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '7:14pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1

#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '7',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 43},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '1.7 km', 'value': 1736},
#       'duration': {'text': '24 mins', 'value': 1450},
#       'end_location': {'lat': 53.2650017, 'lng': -6.1149969},
#       'html_instructions': 'Walk to Scalpwilliam, Killiney, Co. Dublin, Ireland',
#       'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yCJKZ_@P[T]NWHUDKFSDMLcAPcAHg@Fg@`A{@NObAo@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_AV?H_@HYHMl@iAXk@Rk@`@cAb@oADYI{@PBL@TCj@Wh@c@j@Y'},
#       'start_location': {'lat': 53.267384, 'lng': -6.1345433},
#       'steps': [{'distance': {'text': '0.1 km', 'value': 113},
#         'duration': {'text': '1 min', 'value': 83},
#         'end_location': {'lat': 53.2664883, 'lng': -6.1340892},
#         'html_instructions': 'Head <b>south</b> on <b>Thomastown Rd</b> toward <b>Ballinclea Rd</b>',
#         'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@'},
#         'start_location': {'lat': 53.267384, 'lng': -6.1345433},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.7 km', 'value': 715},
#         'duration': {'text': '9 mins', 'value': 562},
#         'end_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'html_instructions': 'Turn <b>left</b> onto <b>Ballinclea Rd</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'qrbdI`amd@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yC'},
#         'start_location': {'lat': 53.2664883, 'lng': -6.1340892},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '90 m', 'value': 90},
#         'duration': {'text': '1 min', 'value': 80},
#         'end_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'html_instructions': 'Turn <b>right</b> toward <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-right',
#         'polyline': {'points': 'ydcdI|gkd@JKZ_@P[T]NWHUDKFS'},
#         'start_location': {'lat': 53.2694111, 'lng': -6.1249495},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.2 km', 'value': 176},
#         'duration': {'text': '3 mins', 'value': 161},
#         'end_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'html_instructions': 'Continue onto <b>Ballinclea Heights</b>',
#         'polyline': {'points': 'aacdIhbkd@DMLcAPcAHg@Fg@`A{@NObAo@'},
#         'start_location': {'lat': 53.2688104, 'lng': -6.1240533},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '0.3 km', 'value': 324},
#         'duration': {'text': '4 mins', 'value': 269},
#         'end_location': {'lat': 53.2669794, 'lng': -6.1177607},
#         'html_instructions': 'Turn <b>left</b> to stay on <b>Ballinclea Heights</b>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'szbdIfwjd@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_A'},
#         'start_location': {'lat': 53.267782, 'lng': -6.1222803},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text':
[YAi@EsAAoABaDDkAdCcQf@aD~AgGVeAt@gCdAdAb@b@rClCjCpCb@b@^iAZaAx@iCzDkLnCmIbBaFFOvBnAB@pF~C|KjG~CjBtDnB?C?A@C@ABAFH?HVR~FhDtK|FHEn@TBGJWXORDJLJVHFf@?vBOrGgAbJcBbE_@dACrBG`PP|Vp@vA_@V[J_@LsAKeBi@wBm@}@}@m@wO_JaBwAoA{AQXqAbEb@z@t@v@T`AIbPhN^hED@g@?b@L?xA?TWZq@DQP@E}BMs@a@oAM[@_AAw@k@kEq@uEy@kEgB}HO[u@aAcB_B]cAM_@m@_Ef@k@f@y@f@mAn@}DFg@`A{@rA_AGcAAgCFoCLaBhAoFz@yCL_AV?Ry@v@wAl@wAdAsCDYI{@^D`A[tA}@'},
#   'summary': '',
#   'warnings': ['Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths.'],
#   'waypoint_order': []},
#  {'bounds': {'northeast': {'lat': 53.36490269999999, 'lng': -6.1068102},
#    'southwest': {'lat': 53.2648407, 'lng': -6.2595337}},
#   'copyrights': 'Map data ©2019',
#   'legs': [{'arrival_time': {'text': '8:58pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562788680},
#     'departure_time': {'text': '7:33pm',
#      'time_zone': 'Europe/Dublin',
#      'value': 1562783638},
#     'distance': {'text': '21.4 km', 'value': 21368},
#     'duration': {'text': '1 hour 24 mins', 'value': 5042},
#     'end_address': 'Scalpwilliam, Killiney, Co. Dublin, Ireland',
#     'end_location': {'lat': 53.2648407, 'lng': -6.1150125},
#     'start_address': 'Clontarf, Fairview, Co. Dublin, Ireland',
#     'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#     'steps': [{'distance': {'text': '58 m', 'value': 58},
#       'duration': {'text': '1 min', 'value': 40},
#       'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#       'html_instructions': 'Walk to Marino, East South B. Sub Station',
#       'polyline': {'points': 'syudIjy_e@|@_CCC'},
#       'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#       'steps': [{'distance': {'text': '55 m', 'value': 55},
#         'duration': {'text': '1 min', 'value': 37},
#         'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001},
#         'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>",
#         'polyline': {'points': 'syudIjy_e@|@_C'},
#         'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '3 m', 'value': 3},
#         'duration': {'text': '1 min', 'value': 3},
#         'end_location': {'lat': 53.3646089, 'lng': -6.2294807},
#         'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'uwudIju_e@CC'},
#         'start_location': {'lat': 53.36458769999999,
#          'lng': -6.229505000000001},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '2.8 km', 'value': 2832},
#       'duration': {'text': '11 mins', 'value': 661},
#       'end_location': {'lat': 53.3479804, 'lng': -6.2566307},
#       'html_instructions': 'Bus towards Dundrum Luas',
#       'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBBb@f@x@`Az@v@JJDDPNBBJFd@Xv@f@d@RBBFBHBt@^vAp@CHnCvAr@x@b@Pr@FxAOj@FBfH?jI?UHrDNvAHlBDn@PG'},
#       'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973},
#       'transit_details': {'arrival_stop': {'location': {'lat': 53.3479804,
#          'lng': -6.2566307},
#         'name': 'Dublin, Marlborough Street'},
#        'arrival_time': {'text': '7:45pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562784339},
#        'departure_stop': {'location': {'lat': 53.36457499999999,
#          'lng': -6.2293973},
#         'name': 'Marino, East South B. Sub Station'},
#        'departure_time': {'text': '7:34pm',
#         'time_zone': 'Europe/Dublin',
#         'value': 1562783678},
#        'headsign': 'Dundrum Luas',
#        'line': {'agencies': [{'name': 'Dublin Bus',
#           'url': 'http://www.transportforireland.ie/'}],
#         'short_name': '14',
#         'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png',
#          'name': 'Bus',
#          'type': 'BUS'}},
#        'num_stops': 9},
#       'travel_mode': 'TRANSIT'},
#      {'distance': {'text': '0.2 km', 'value': 216},
#       'duration': {'text': '3 mins', 'value': 169},
#       'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#       'html_instructions': "Walk to O'Connell Bridge Bus Stop",
#       'polyline': {'points': 'oprdId_ee@Fv@NpABRFf@d@vD@JHh@Ht@NEHIFCj@U'},
#       'start_location': {'lat': 53.3480763, 'lng': -6.2566725},
#       'steps': [{'distance': {'text': '0.2 km', 'value': 171},
#         'duration': {'text': '2 mins', 'value': 128},
#         'end_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'html_instructions': 'Head <b>west</b> on <b>Eden Quay</b>/<b>R105</b> toward <b>Marlborough St</b>',
#         'polyline': {'points': 'oprdId_ee@Fv@NpABRFf@d@vD@JHh@Ht@'},
#         'start_location': {'lat': 53.3480763, 'lng': -6.2566725},
#         'travel_mode': 'WALKING'},
#        {'distance': {'text': '45 m', 'value': 45},
#         'duration': {'text': '1 min', 'value': 41},
#         'end_location': {'lat': 53.3472145, 'lng': -6.2589095},
#         'html_instructions': 'Turn <b>left</b> onto <b>O\'Connell Bridge</b><div style="font-size:0.9em">Destination will be on the left</div>',
#         'maneuver': 'turn-left',
#         'polyline': {'points': 'omrdInnee@NEHIFCj@U'},
#         'start_location': {'lat': 53.3475955, 'lng': -6.2591161},
#         'travel_mode': 'WALKING'}],
#       'travel_mode': 'WALKING'},
#      {'distance': {'text': '12.1 km', 'value': 12083},
#       'duration': {'text': '34 mins', 'value': 2060},
#       'end_location': {'lat': 53.29017030000001, 'lng': -6.131013},
#       'html_instructions': 'Bus towards Loughlinstown Pk',
#       'polyline': {'points': 'gkrdIjlee@DRrA{@n@u@zBqDNOJARLbAdEz@rBb@j@pAbAjA{@PCt@Af@LV@LIVe@xC}SDa@h@cEf@uDP_B@CBUBg@@S@e@JQDIBGLa@DMTeAFOb@kBTy@DQ`@_BNm@x@gD~AqGH]@?VeARu@V_AViA^uAPs@FWVgAFWh@_Cb@cBAC@BPm@VaAFWDOVcALo@BILc@DUH]`@mBP}@h@gCFSHSPg@JORa@x@_BVe@NW^o@l@_Az@wANOf@_@@Af@]^[v@c@d@Wx@i@j@]l@a@TMnCgB`Ao@NIZSx@e@h@]XOPQ~@u@^k@V_@HMlDoENQJQJS`@k@x@iAf@y@n@kAXs@t@}BFUBETq@BIFQLg
#  dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])]

# %%
a["routes"][0]["bounds"]
# Out:
# {'northeast': {'lat': 53.36490269999999, 'lng': -6.1149969},
#  'southwest': {'lat': 53.2650017, 'lng': -6.2595337}}

# %%
# Shows all the steps in a trip
for i, val in enumerate(a["routes"][0]["legs"][0]["steps"]):
    print(i)
    print(val)
# Out:
# 0
# {'distance': {'text': '58 m', 'value': 58}, 'duration': {'text': '1 min', 'value': 40}, 'end_location': {'lat': 53.3646089, 'lng': -6.2294807}, 'html_instructions': 'Walk to Marino, East South B. Sub Station', 'polyline': {'points': 'syudIjy_e@|@_CCC'}, 'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364}, 'steps': [{'distance': {'text': '55 m', 'value': 55}, 'duration': {'text': '1 min', 'value': 37}, 'end_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001}, 'html_instructions': "Head <b>southeast</b> on <b>St Aidan's Park Rd</b> toward <b>Malahide Rd</b>/<b>R107</b>", 'polyline': {'points': 'syudIjy_e@|@_C'}, 'start_location': {'lat': 53.36490269999999, 'lng': -6.2301364}, 'travel_mode': 'WALKING'}, {'distance': {'text': '3 m', 'value': 3}, 'duration': {'text': '1 min', 'value': 3}, 'end_location': {'lat': 53.3646089, 'lng': -6.2294807}, 'html_instructions': 'Turn <b>left</b> onto <b>Malahide Rd</b>/<b>R107</b><div style="font-size:0.9em">Destination will be on the right</div>', 'maneuver': 'turn-left', 'polyline': {'points': 'uwudIju_e@CC'}, 'start_location': {'lat': 53.36458769999999, 'lng': -6.229505000000001}, 'travel_mode': 'WALKING'}], 'travel_mode': 'WALKING'}
# 1
# {'distance': {'text': '2.9 km', 'value': 2944}, 'duration': {'text': '10 mins', 'value': 622}, 'end_location': {'lat': 53.34775459999999, 'lng': -6.2584683}, 'html_instructions': 'Bus towards Eden Quay', 'polyline': {'points': 'qwudIvt_e@GNBBd@|@LBG`@Bd@Bx@@T@RD`A@b@@DB^Dh@Hr@Jn@Jr@Nz@VtAP~@H\\j@zCPz@r@lDFXTfAJd@Dh@NP`@f@HHb@h@xAhBDIrBdCrCxDLLtBtBjGbHbC~DHLPXr@rAJPNVn@fAVd@LR@BXf@FNJP^l@DFLTJPPXNVVb@@@Zh@X`@V`@V^t@bAb@j@V^RPPP\\b@`@d@LL^`@FFf@h@FFl@p@zAdBJLDF^f@PVPPBB?ArA|ApBrBzLtGr@x@t@X~@?z@Oj@FBfH?jI?UHrDPhBlArN'}, 'start_location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'transit_details': {'arrival_stop': {'location': {'lat': 53.34775459999999, 'lng': -6.2584683}, 'name': 'Dublin, Eden Quay'}, 'arrival_time': {'text': '7:26pm', 'time_zone': 'Europe/Dublin', 'value': 1562783182}, 'departure_stop': {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}, 'departure_time': {'text': '7:16pm', 'time_zone': 'Europe/Dublin', 'value': 1562782560}, 'headsign': 'Eden Quay', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '27b', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.
vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 43}, 'travel_mode': 'TRANSIT'}
# 4
# {'distance': {'text': '1.7 km', 'value': 1736}, 'duration': {'text': '24 mins', 'value': 1450}, 'end_location': {'lat': 53.2650017, 'lng': -6.1149969}, 'html_instructions': 'Walk to Scalpwilliam, Killiney, Co. Dublin, Ireland', 'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yCJKZ_@P[T]NWHUDKFSDMLcAPcAHg@Fg@`A{@NObAo@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_AV?H_@HYHMl@iAXk@Rk@`@cAb@oADYI{@PBL@TCj@Wh@c@j@Y'}, 'start_location': {'lat': 53.267384, 'lng': -6.1345433}, 'steps': [{'distance': {'text': '0.1 km', 'value': 113}, 'duration': {'text': '1 min', 'value': 83}, 'end_location': {'lat': 53.2664883, 'lng': -6.1340892}, 'html_instructions': 'Head <b>south</b> on <b>Thomastown Rd</b> toward <b>Ballinclea Rd</b>', 'polyline': {'points': 'cxbdIzcmd@L?pA@FADCNSR_@FQ@GBID?J@'}, 'start_location': {'lat': 53.267384, 'lng': -6.1345433}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.7 km', 'value': 715}, 'duration': {'text': '9 mins', 'value': 562}, 'end_location': {'lat': 53.2694111, 'lng': -6.1249495}, 'html_instructions': 'Turn <b>left</b> onto <b>Ballinclea Rd</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'qrbdI`amd@@[AYAe@Ca@?KMg@W{@ISM[@_A?_@AWCSGo@Ky@SmAQkA_@iCQ_Ag@kC[yAc@gB_@eBGUKSCGKQi@o@c@e@_Ay@M_@Oc@AEKYKe@a@yC'}, 'start_location': {'lat': 53.2664883, 'lng': -6.1340892}, 'travel_mode': 'WALKING'}, {'distance': {'text': '90 m', 'value': 90}, 'duration': {'text': '1 min', 'value': 80}, 'end_location': {'lat': 53.2688104, 'lng': -6.1240533}, 'html_instructions': 'Turn <b>right</b> toward <b>Ballinclea Heights</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'ydcdI|gkd@JKZ_@P[T]NWHUDKFS'}, 'start_location': {'lat': 53.2694111, 'lng': -6.1249495}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.2 km', 'value': 176}, 'duration': {'text': '3 mins', 'value': 161}, 'end_location': {'lat': 53.267782, 'lng': -6.1222803}, 'html_instructions': 'Continue onto <b>Ballinclea Heights</b>', 'polyline': {'points': 'aacdIhbkd@DMLcAPcAHg@Fg@`A{@NObAo@'}, 'start_location': {'lat': 53.2688104, 'lng': -6.1240533}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.3 km', 'value': 324}, 'duration': {'text': '4 mins', 'value': 269}, 'end_location': {'lat': 53.2669794, 'lng': -6.1177607}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Ballinclea Heights</b>', 'maneuver': 'turn-left', 'polyline': {'points': 'szbdIfwjd@E[Ag@Ay@?mA@mADaAFw@Di@PgATs@P{@Nw@Lg@Rw@J]L[L_A'}, 'start_location': {'lat': 53.267782, 'lng': -6.1222803}, 'travel_mode': 'WALKING'}, {'distance': {'text': '13 m', 'value': 13}, 'duration': {'text': '1 min', 'value': 15}, 'end_location': {'lat': 53.26685939999999, 'lng': -6.1177624}, 'html_instructions': 'Turn <b>right</b> onto <b>Rock Lodge</b>', 'maneuver': 'turn-right', 'polyline': {'points': 'subdI~zid@V?'}, 'start_location': {'lat': 53.2669794, 'lng': -6.1177607}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.2 km', 'value': 176}, 'duration': {'text': '3 mins', 'value': 176}, 'end_location': {'lat': 53.26587, 'lng': -6.11572}, 'html_instructions': 'Turn <b>left</b> to stay on <b>Rock Lodge</b>', 'maneuver': 'turn-left', 'polyline': {'points': '{tbdI~zid@H_@HYHMl@iAXk@Rk@`@cAb@oADY'}, 'start_location': {'lat': 53.26685939999999, 'lng': -6.1177624}, 'travel_mode': 'WALKING'}, {'distance': {'text': '21 m', 'value': 21}, 'duration': {'text': '1 min', 'value': 20}, 'end_location': {'lat': 53.2659218, 'lng': -6.115418699999999}, 'html_instructions': 'Slight <b>left</b> onto <b>Claremont Rd</b>', 'maneuver': 'turn-slight-left', 'polyline': {'points': 'unbdIfnid@I{@'}, 'start_location': {'lat': 53.26587, 'lng': -6.11572}, 'travel_mode': 'WALKING'}, {'distance': {'text': '0.1 km', 'value': 108}, 'duration': {'text': '1 min', 'value': 84}, 'end_location': {'lat': 53.2650017, 'lng': -6.1149969}, 'html_instructions': 'Turn <b>right</b> onto <b>Killiney Hill Rd</b><div style="font-size:0.9em">D ...

# %%
# Shows only steps with bus 
print(a["routes"][0]["legs"][0]["steps"][1]["transit_details"])
# Out:
# {'arrival_stop': {'location': {'lat': 53.34775459999999, 'lng': -6.2584683}, 'name': 'Dublin, Eden Quay'}, 'arrival_time': {'text': '7:26pm', 'time_zone': 'Europe/Dublin', 'value': 1562783182}, 'departure_stop': {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}, 'departure_time': {'text': '7:16pm', 'time_zone': 'Europe/Dublin', 'value': 1562782560}, 'headsign': 'Eden Quay', 'line': {'agencies': [{'name': 'Dublin Bus', 'url': 'http://www.transportforireland.ie/'}], 'short_name': '27b', 'vehicle': {'icon': '//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png', 'name': 'Bus', 'type': 'BUS'}}, 'num_stops': 8}

# %%
print("vehicle: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["vehicle"]["type"])
print()
print("dep stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"])
print()
print("arr stop: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"])
print()
print("headsign: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["headsign"])
print()
print("route name: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["line"]["short_name"])
print()
print("num_stops: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["num_stops"])
print()
print("dep time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
print()
print("arri time: ", a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
print()
arr = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_time"]["value"])
dep = int(a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_time"]["value"])
tot = datetime.timedelta(seconds=(arr - dep))
print("total time: ", tot)
# Out:
# vehicle:  BUS
#
# dep stop:  {'location': {'lat': 53.36457499999999, 'lng': -6.2293973}, 'name': 'Marino, East South B. Sub Station'}
#
# arr stop:  Dublin, Eden Quay
#
# headsign:  Eden Quay
#
# route name:  27b
#
# num_stops:  8
#
# dep time:  1562782560
#
# arri time:  1562783182
#
# total time:  0:10:22

# %%
for i in range(len(route_keys)):
    for j in range(len(a["routes"][i]["legs"][0]["steps"])):
    
        if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
            print("Vehicle: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"])
            
            print("dep stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"])
            
            print("arr stop: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"])
            
            print("headsign: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"])
                  
            print("route name: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"])
                  
            print("num_stops: ", a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["num_stops"])
            
            arr = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_time"]["value"])
            dep = int(a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_time"]["value"])
            tot = datetime.timedelta(seconds=(arr - dep))
            print("totalbus trip time: ", tot)
                  
            print("step number", j)
            print("option number:", i)
            print()
            
    print("-----------------------------------------------------")
    print()
# Out:
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Dublin, Eden Quay
# headsign:  Eden Quay
# route name:  27b
# num_stops:  8
# totalbus trip time:  0:10:22
# step number 1
# option number: 0
#
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  Glenageary Heights, Sallyglen
# headsign:  Brides Glen
# route name:  7
# num_stops:  43
# totalbus trip time:  0:41:51
# step number 3
# option number: 0
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Clifton Court Hotel Eden Quay
# headsign:  Jobstown
# route name:  27
# num_stops:  9
# totalbus trip time:  0:10:43
# step number 1
# option number: 1
#
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  George's St Upper
# headsign:  Loughlinstown Pk
# route name:  7a
# num_stops:  37
# totalbus trip time:  0:34:20
# step number 3
# option number: 1
#
# Vehicle:  BUS
# dep stop:  George's St Upper
# arr stop:  Killiney, Killiney Hill Road
# headsign:  Town Hall - Ballymount Depot
# route name:  59
# num_stops:  20
# totalbus trip time:  0:17:00
# step number 4
# option number: 1
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Dublin City South, Ashfield House
# headsign:  Dundrum Luas
# route name:  14
# num_stops:  10
# totalbus trip time:  0:14:54
# step number 1
# option number: 2
#
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  Glenageary Heights, Sallyglen
# headsign:  Brides Glen
# route name:  7
# num_stops:  43
# totalbus trip time:  0:41:51
# step number 3
# option number: 2
#
# -----------------------------------------------------
#
# Vehicle:  BUS
# dep stop:  Marino, East South B. Sub Station
# arr stop:  Dublin, Marlborough Street
# headsign:  Dundrum Luas
# route name:  14
# num_stops:  9
# totalbus trip time:  0:11:01
# step number 1
# option number: 3
#
# Vehicle:  BUS
# dep stop:  O'Connell Bridge Bus Stop
# arr stop:  George's St Upper
# headsign:  Loughlinstown Pk
# route name:  7a
# num_stops:  37
# totalbus trip time:  0:34:20
# step number 3
# option number: 3
#
# Vehicle:  BUS
# dep stop:  George's St Upper
# arr stop:  Killiney, Killiney Hill Road
# headsign:  Town Hall - Ballymount Depot
# route name:  59
# num_stops:  20
# totalbus trip time:  0:17:00
# step number 4
# option number: 3
#
# -----------------------------------------------------

# %%
# This are stop names not addresses:

stopA = "Outside Heuston Train Station"
stopB = "Temple Bar, Parliament Street"

# stopA = "Outside Heuston Train Station"
# stopB = "Temple Bar, Parliament Street"

# stopA = "O'Connell Bridge Bus Stop"
# stopB = "Glenageary Heights, Sallyglen"

# stopA = "Dublin City South, Camden Street"
# stopB = "Fairview, Marino College Fairview"

# stopA = "Dublin (UCD Stillorgan Rd Flyover)"
# stopB = "Dublin City South, Essex Quay"

# stopA = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["departure_stop"]["name"]
# stopB = a["routes"][0]["legs"][0]["steps"][1]["transit_details"]["arrival_stop"]["name"]
# print(stopA)
# print(stopB)


query1 = """SELECT stop_lat,stop_lon,stop_id,stop_name 
        FROM research.stops 
        WHERE stop_name LIKE %s or stop_name LIKE %s"""

query2 = """SELECT distinct research.stop_times.bus_number  
        FROM research.stop_times 
        WHERE research.stop_times.bus_number=%s and research.stop_times.bus_stop_number=%s and research.stop_times.headsign=%s"""


query3 = """SELECT research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.trips.direction_id, research.stop_times.headsign 
        FROM research.stop_times, research.trips 
        WHERE stop_times.trip_id = trips.trip_id and stop_times.headsign = %s and stop_times.bus_number = %s and (bus_stop_number = %s or bus_stop_number = %s)"""


query4 = """SELECT research.stops.stop_lat, research.stops.stop_lon, research.stop_times.bus_stop_number, research.stop_times.stop_sequence, research.stop_times.headsign, research.stop_times.bus_number 
        FROM research.stop_times, research.stops
        WHERE bus_number = %s and headsign = %s and (stop_sequence between %s AND %s)
        LIMIT %s
        """

# %%
def fuzz(stopA, stopB):
    data = tuple()
    with open('stops.csv', encoding="utf8") as read_file:
        read_csv = csv.reader(read_file, delimiter=",")
        
        oconnell = "O'Connell Bridge"
        
        if oconnell in stopA:
            stopA = oconnell
        if oconnell in stopB:
            stopB = oconnell
        
        countA = 0
        countB = 0
                
        dataA = [()]
        dataB = [()]
            
        for i, row in enumerate(read_csv):
            if i == 0:
                continue
            else:
                stopA_ratio = difflib.SequenceMatcher(None, stopA, row[4]).ratio()
                stopB_ratio = difflib.SequenceMatcher(None, stopB, row[4]).ratio()
                
                if stopA_ratio > countA:
                    countA = stopA_ratio
                    dataA[0] = (row[0], row[2], row[3], row[4])

                if stopB_ratio > countB:
                    countB = stopB_ratio
                    dataB[0] = (row[0], row[2], row[3], row[4])
                    
                
        data += dataA[0]
        data += dataB[0]
                                        
            
    read_file.close()

    return data

fuzz(stopA, stopB)
# Out:
# ('53.3461643943',
#  '-6.29271836681',
#  '8220DB004413',
#  'Outside Heuston Train Station',
#  '53.3446304775',
#  '-6.26736693757',
#  '8220DB002912',
#  'Temple Bar, Parliament Street')

# %%
def db_query(query, stopA, stopB):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    key_words = ["Bus", "Stop", "O'", "'"]
    
    for word in key_words:
        if word in stopA:
            stopA = stopA.replace(word, "")
        if word in stopB:
            stopB = stopB.replace(word, "")
    print(stopA)
    print(stopB)
    
    cur = con.cursor()
    cur.execute(query, ("%"+stopA+"%", "%"+stopB+"%"), )
    data = cur.fetchall()
    cur.close()   
      
    
    return data

# %%
b = db_query(query1, stopA, stopB)
b
# Out:
# Dublin (UCD Stillorgan Rd Flyover)
# Dublin City South, Essex Quay
# (('53.3451293907',
#   '-6.26953955863',
#   '8220DB001443',
#   'Dublin City South, Essex Quay'),
#  ('53.309418194',
#   '-6.21877482979',
#   '8250DB000768',
#   'Dublin (UCD Stillorgan Rd Flyover)'))

# %%
def db_query2(query, bus_no, stop_no, head_sign):

    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host, database=database, user=user, password=password)
    except Exception as e:
        sys.exit(e)

    cur = con.cursor()
    cur.execute(query, (bus_no, stop_no, head_sign),)
    data = list(cur.fetchall())

    if len(data) > 0:
        data.pop()
        data.append(bus_no)
        data.append(head_sign)
    cur.close()
    
    return data

# %%
def start_end(b, bus_no, headsign):
# def start_end(b):
    c = []
    
    for i in b:
        
#         z = db_query2(query2, "145", i[2], "Heuston Station")
        z = db_query2(query2, bus_no, i[2], headsign)

        if(len(z) != 0):
            z.append(i[0])
            z.append(i[1])
            z.append(i[2])
            z.append(i[3])
            c.append(z)
    return c

# %%
def db_query3(query, head_sign, bus_no, stop_noA, stop_noB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
        
    cur = con.cursor()
    cur.execute(query, (head_sign, bus_no, stop_noA, stop_noB),)
    cur.close()
    return cur.fetchall()

# %%
# e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4])
# e

# %%
def db_query4(query, bus_no, head_sign, seqA, seqB):
    
    user='root'
    password='migmarache1982'
    host='127.0.0.1'
    database='research'

    try:
        con = pymysql.connect(host=host,database=database,user=user, password=password)
    except Exception as e:
        sys.exit(e)
    limit = seqB - seqA + 1
    cur = con.cursor()
    cur.execute(query, (bus_no, head_sign, seqA, seqB, limit),)
    cur.close()
    return cur.fetchall()

# %%
# f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
# f

# %%
# a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS"
# a["routes"][0]["legs"][0]["steps"][0]

# %%
final_list = []

def fin(a):
    
    route_keys = [a["routes"][i].keys() for i, k in enumerate(a["routes"])]
    
    for i in range(len(route_keys)):
        should_count = 0
        is_count = 0
        interm_legs = []
        for j in range(len(a["routes"][i]["legs"][0]["steps"])):
            
            if "transit_details" in a["routes"][i]["legs"][0]["steps"][j] and a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["vehicle"]["type"] == "BUS":
                should_count += 1
                dep_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["departure_stop"]["name"]
                arr_stop = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["arrival_stop"]["name"]
                bus_no = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["line"]["short_name"]
                head_sign = a["routes"][i]["legs"][0]["steps"][j]["transit_details"]["headsign"]
                
                b = db_query(query1, dep_stop, arr_stop)
                print("Query 1: ")
                print(b)
                if len(b) > 1:
                    d = start_end(b, bus_no, head_sign)
                    print("Query 2: ")
                    print(d)
                    e = db_query3(query3, d[0][1], d[0][0], d[0][4], d[1][4]) 
                    print("Query 3: ")
                    print(e)
                    if (len(e) > 0):
                        f = db_query4(query4, d[0][0], e[0][3], e[0][1], e[1][1])
                        print("Final: ")
                        print(f)
                        is_count += 1
                        interm_legs.append(f)                            
                        
                    else:
                        pass
                else:
                    pass
                print("step: ", j)
            else:
                pass
            
            
            
        if should_count == is_count:
            print("Number of positive legs obtained: ", len(interm_legs))
            final_list.append(interm_legs)
        else:
            print("Number of positive legs is NOT valid with", len(interm_legs))
                
        
        print("option: ", i)
        print("*****************************************************************")
        
fin(a)
# Out:
# Marino, East South B. Sub Station
#    Eden Quay
# Query 1:
# (('53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'),)
# step:  1
# Connell Bridge
# Sallynoggin, Killiney Shopping Centre
# Query 1:
# (('53.2670619925', '-6.13623408219', '8250DB003213', 'Sallynoggin, Killiney Shopping Centre'),)
# step:  3
# Number of positive legs is NOT valid with 0
# option:  0
# *****************************************************************
# Marino, East South B. Sub Station
# Dublin, Eden Quay
# Query 1:
# (('53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'), ('53.3480937576', '-6.25707255846', '8220DB000297', 'Dublin, Eden Quay'), ('53.3481136752', '-6.2559752408', '8220DB000303', 'Dublin, Eden Quay'), ('53.348065922', '-6.25639776708', '8220DB000302', 'Dublin, Eden Quay'))
# Query 2:
# [['27b', 'Eden Quay', '53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'], ['27b', 'Eden Quay', '53.3481136752', '-6.2559752408', '8220DB000303', 'Dublin, Eden Quay']]
# Query 3:
# (('8220DB000668', 37, '1', 'Eden Quay'), ('8220DB000303', 45, '1', 'Eden Quay'), ('8220DB000668', 35, '1', 'Eden Quay'), ('8220DB000303', 43, '1', 'Eden Quay'), ('8220DB000668', 22, '1', 'Eden Quay'), ('8220DB000303', 30, '1', 'Eden Quay'), ('8220DB000668', 32, '1', 'Eden Quay'), ('8220DB000303', 40, '1', 'Eden Quay'), ('8220DB000668', 25, '1', 'Eden Quay'), ('8220DB000303', 33, '1', 'Eden Quay'))
# Final:
# (('53.2480439849', '-6.12315403365', '8220DB000668', 37, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000614', 38, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000615', 39, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000616', 40, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000617', 41, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000618', 42, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000619', 43, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000675', 44, 'Eden Quay', '27B'), ('53.2480439849', '-6.12315403365', '8220DB000303', 45, 'Eden Quay', '27B'))
# step:  1
# Connell Bridge
# Sallynoggin, Killiney Shopping Centre
# Query 1:
# (('53.2670619925', '-6.13623408219', '8250DB003213', 'Sallynoggin, Killiney Shopping Centre'),)
# step:  3
# Number of positive legs is NOT valid with 1
# option:  1
# *****************************************************************
# Marino, East South B. Sub Station
#    Eden Quay
# Query 1:
# (('53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'),)
# step:  1
# Connell Bridge
# Glenageary Heights, Sallyglen
# Query 1:
# (('53.274314435', '-6.13443403413', '8250DB007642', 'Glenageary Heights, Sallyglen'), ('53.2673832402', '-6.13436102873', '8250DB007643', 'Glenageary Heights, Sallyglen'), ('53.267642481', '-6.13484449848', '8250DB007644', 'Glenageary Heights, Sallyglen'), ('53.2751003475', '-6.13468471509', '8250DB007645', 'Glenageary Heights, Sallyglen'), ('53.2790894969', '-6.13572570552', '8250DB007646', 'Glenageary Heights, Sallyglen'))
# Query 2:
# [['7', 'Brides Glen', '53.274314435', '-6.13443403413', '8250DB007642', 'Glenageary Heights, Sallyglen'], ['7', 'Brides Glen', '53.2673832402', '-6.13436102873', '8250DB007643', 'Glenageary Heights, Sallyglen']]
# Query 3:
# ()
# step:  3
# Number of positive legs is NOT valid with 0
# option:  2
# *****************************************************************
# Marino, East South B. Sub Station
# Dublin, Marlborough Street
# Query 1:
# (('53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'), ('53.3530905892', '-6.2601134999', '8220DB006071', 'Dublin, Marlborough Street'), ('53.3479491562', '-6.25701837558', '8220DB000301', 'Dublin, Marlborough Street'))
# Query 2:
# [['15', 'Ballycullen Road', '53.3645749809', '-6.22939731689', '8220DB000668', 'Marino, East South B. Sub Station'], ['15', 'Ballycullen Road', '53.3479491562', '-6.25701837558', '8220DB000301', 'Dublin, Marlborough Street']]
# Query 3:
# ()
# step:  1
# Connell Bridge
# Sallynoggin, Killiney Shopping Centre
# Query 1:
# (('53.2670619925', '-6.13623408219', '8250DB003213', 'Sallynoggin, Killiney Shopping Centre'),)
# step:  3
# Number of positive legs is NOT valid with 0
# option:  3
# *****************************************************************

# %%
print(len(final_list))

# %%
final_list[0]
